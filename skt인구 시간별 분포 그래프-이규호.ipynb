# %%
#임포트와 구글마운트
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#데이터 연결(성별나이)
age1902= pd.read_csv(''/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_AGE_201902.CSV', sep = '|')
age1903= pd.read_csv(r'/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_AGE_201903.CSV', sep = '|')
age1904= pd.read_csv(r'/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_AGE_201904.CSV', sep = '|')
age1904= pd.read_csv(r'/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_AGE_201905.CSV', sep = '|')
age2002= pd.read_csv(r'/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_AGE_202002.CSV', sep = '|')
age2003= pd.read_csv(r'/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_AGE_202003.CSV', sep = '|')
age2004= pd.read_csv(r'/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_AGE_202004.CSV', sep = '|')
age2005= pd.read_csv(r'/content/drive/My Drive/2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_AGE_202005.CSV', sep = '|')

# %%
#데이터 연결(시간)
time1902= pd.read_csv('./2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_TIME_201902.CSV', sep = '|')
time1903= pd.read_csv('./2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_TIME_201903.CSV', sep = '|')
time1904= pd.read_csv('./2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_TIME_201904.CSV', sep = '|')
time1905= pd.read_csv('./2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_TIME_201905.CSV', sep = '|')
time2002= pd.read_csv('./2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_TIME_202002.CSV', sep = '|')
time2003= pd.read_csv('./2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_TIME_202003.CSV', sep = '|')
time2004= pd.read_csv('./2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_TIME_202004.CSV', sep = '|')
time2005= pd.read_csv('./2020빅콘테스트 문제데이터(혁신아이디어분야)/01_유동인구데이터(SK텔레콤)/4개지역_FLOW_TIME_202005.CSV', sep = '|')

# %% [markdown]
# #완성된 함수

# %%
# 4개 구에 대한 그래프 그리는 함수. 원하는 데이터프레임과 날짜넣으면 찾아서표시해줌  
def Drawing(df, day):
  df1= df[69*(day-1):69*(day-1)+15]
  df2= df[69*(day-1)+15:69*(day-1)+34]
  df3= df[69*(day-1)+34:69*(day-1)+46]
  df4= df[69*(day-1)+46:69*(day-1)+69]
  df_seoul = pd.concat([df1, df2])
  df_deagu = pd.concat([df3, df4])
  df_total = pd.concat([df_seoul, df_deagu])

  
#   df1.iloc[:,4:].T.plot(figsize=(20,10))
#   plt.legend(df1.iloc[:,3])
#   plt.title("Seoul JungGu")
#   plt.xlabel("Time")
#   plt.ylabel("Number of Population")
#   plt.grid()
#   plt.show()

  df2.iloc[:,4:].T.plot(figsize=(20,10))
  plt.legend(df2.iloc[:,3])
  plt.title("Seoul NowonGu")
  plt.xlabel("Time")
  plt.ylabel("Number of Population")
  plt.grid()
  plt.show()

#   df3.iloc[:,4:].T.plot(figsize=(20,10))
#   plt.legend(df3.iloc[:,3])
#   plt.title("Deagu JungGu")
#   plt.xlabel("Time")
#   plt.ylabel("Number of Population")
#   plt.grid()
#   plt.show()

#   df4.iloc[:,4:].T.plot(figsize=(20,10))
#   plt.legend(df4.iloc[:,3])
#   plt.title("Deagu SusungGu")
#   plt.xlabel("Time")
#   plt.ylabel("Number of Population")
#   plt.grid()
#   plt.show()
  
  #서울전체 보고싶으면 아래코드 활성화
  # df_seoul.iloc[:,4:].T.plot(figsize=(20,10))
  # plt.legend(df_seoul.iloc[:,3])
  # plt.title("Seoul")
  # plt.xlabel("Time")
  # plt.ylabel("Number of Population")
  # plt.grid()
  # plt.show()
  
  #대구전체 보고싶으면 아래코드 활성화
  # df_deagu.iloc[:,4:].T.plot(figsize=(20,10))
  # plt.legend(df_deagu.iloc[:,3])
  # plt.title("Deagu")
  # plt.xlabel("Time")
  # plt.ylabel("Number of Population")
  # plt.grid()
  # plt.show()
  
  #전체 보고싶으면 아래코드 활성화
  # df_total.iloc[:,4:].T.plot(figsize=(20,10))
  # plt.legend(df_total.iloc[:,3])
  # plt.title("Total")
  # plt.xlabel("Time")
  # plt.ylabel("Number of Population")
  # plt.grid()
  # plt.show()

# %%
Drawing(time2003, 8)
Drawing(time2003, 15)

# %%
#구별로 합쳐서 볼 수 있는 함수
def TotalDrawing(df, day):
  time_col = df.columns
  
  df1= df[69*(day-1):69*(day-1)+15]
  df2= df[69*(day-1)+15:69*(day-1)+34]
  df3= df[69*(day-1)+34:69*(day-1)+46]
  df4= df[69*(day-1)+46:69*(day-1)+69]

  timepop1=[]
  for i in time_col[4:]:
    timepop1.append(df1[i].sum())

  timepop2=[]
  for i in time_col[4:]:
    timepop2.append(df2[i].sum())

  timepop3=[]
  for i in time_col[4:]:
    timepop3.append(df3[i].sum())

  timepop4=[]
  for i in time_col[4:]:
    timepop4.append(df4[i].sum())

  total_df = pd.DataFrame({'Seoul JungGu' : timepop1,  'Seoul NowonGu' : timepop2, 'Deagu JungGu' : timepop3, 'Daegu SusungGu' : timepop4})

  total_df.plot(figsize=(20,10))
  plt.legend(total_df)
  plt.title("Total")
  plt.xlabel("Time")
  plt.ylabel("Number of Population")
  plt.grid()
  plt.show()

# %%
TotalDrawing(time1902, 2)

# %% [markdown]
# #아래로는 이런저런 시도들이라 볼필요X

# %% [markdown]
# #나이별 차트

# %%
age_col = age1.columns
age1.head()
# Out:
#    STD_YM   STD_YMD  ...  WMAN_FLOW_POP_CNT_6569 WMAN_FLOW_POP_CNT_70U
# 0  201902  20190201  ...                 3359.85               4431.71
# 1  201902  20190202  ...                 2453.97               3207.26
# 2  201902  20190203  ...                 1511.67               1954.98
# 3  201902  20190204  ...                 1230.21               1520.35
# 4  201902  20190205  ...                 1692.74               2147.09
#
# [5 rows x 34 columns]

# %%
age1902['HDONG_NM'].unique()
# Out:
# array(['소공동', '회현동', '명동', '필동', '장충동', '광희동', '을지로동', '신당동', '다산동',
#        '약수동', '청구동', '신당5동', '동화동', '황학동', '중림동', '월계1동', '월계2동', '월계3동',
#        '공릉1동', '공릉2동', '하계1동', '하계2동', '중계본동', '중계1동', '중계4동', '중계2.3동',
#        '상계1동', '상계2동', '상계3.4동', '상계5동', '상계6.7동', '상계8동', '상계9동',
#        '상계10동', '동인동', '삼덕동', '성내1동', '성내2동', '성내3동', '대신동', '남산1동',
#        '남산2동', '남산3동', '남산4동', '대봉1동', '대봉2동', '범어1동', '범어2동', '범어3동',
#        '범어4동', '만촌1동', '만촌2동', '만촌3동', '수성1가동', '수성2.3가동', '수성4가동',
#        '황금1동', '황금2동', '중동', '상동', '파동', '두산동', '지산1동', '지산2동', '범물1동',
#        '범물2동', '고산1동', '고산2동', '고산3동'], dtype=object)

# %%
test1 = age1902[age_col[4:]].iloc[:1]

# %%
test1.plot.bar(figsize=(20, 10))
plt.grid()

plt.show()

# %% [markdown]
# #시간별 차트

# %%
time1902
# Out:
#       STD_YM   STD_YMD    HDONG_CD  ...   TMST_21  TMST_22  TMST_23
# 0     201902  20190201  1114052000  ...   6047.05  4806.65  2956.11
# 1     201902  20190201  1114054000  ...   9341.24  6884.91  4034.56
# 2     201902  20190201  1114055000  ...   8719.30  7203.45  4845.48
# 3     201902  20190201  1114057000  ...   4088.53  3385.14  1746.28
# 4     201902  20190201  1114058000  ...   2626.12  2415.41  1398.94
# ...      ...       ...         ...  ...       ...      ...      ...
# 1927  201902  20190228  2726066100  ...   1730.08  1278.94   826.15
# 1928  201902  20190228  2726066200  ...   1233.50   986.67   596.44
# 1929  201902  20190228  2726067000  ...   6078.16  4467.96  2746.27
# 1930  201902  20190228  2726068000  ...  10419.95  7859.83  4817.53
# 1931  201902  20190228  2726069000  ...   2728.98  2193.95  1305.95
#
# [1932 rows x 28 columns]

# %%
time_col = time1902.columns
time_col
# Out:
# Index(['STD_YM', 'STD_YMD', 'HDONG_CD', 'HDONG_NM', 'TMST_00', 'TMST_01',
#        'TMST_02', 'TMST_03', 'TMST_04', 'TMST_05', 'TMST_06', 'TMST_07',
#        'TMST_08', 'TMST_09', 'TMST_10', 'TMST_11', 'TMST_12', 'TMST_13',
#        'TMST_14', 'TMST_15', 'TMST_16', 'TMST_17', 'TMST_18', 'TMST_19',
#        'TMST_20', 'TMST_21', 'TMST_22', 'TMST_23'],
#       dtype='object')

# %%
len(time1902['HDONG_CD'].unique())#동의 갯수가 69개니까 나누기 위해 포문을 돌리고, 날짜별로 나눠져서 SUM할 수 있겠다.
# Out:
# 69

# %%
time1902.shape[0]/69
# Out:
# 28.0

# %%
time1903.shape[0]/69
# Out:
# 31.0

# %%
for i in range(int(time1902.shape[0]/69)):
  df1= time1[69*i:69*i+15]
  df2= time1[69*i+15:69*i+34]
  df3= time1[69*i+34:69*i+46]
  df4= time1[69*i+46:69*i+70]
  #함수로 발전시켜보자

# %%
df1.shape
# Out:
# (15, 28)

# %%
df2.shape
# Out:
# (19, 28)

# %%
df3.shape
# Out:
# (12, 28)

# %%
df4.shape
# Out:
# (23, 28)

# %%
# 원하는 데이터프레임과 날짜를 집어넣으면 서울중구, 서울노원구, 대구중구, 대구수성구로 뽑는 함수
def datepop(df, day):
  df1= df[69*(day-1):69*(day-1)+15]
  df2= df[69*(day-1)+15:69*(day-1)+34]
  df3= df[69*(day-1)+34:69*(day-1)+46]
  df4= df[69*(day-1)+46:69*(day-1)+70]
  df_seoul = pd.concat([df1, df2])
  df_deagu = pd.concat([df3, df4])
  return df1, df2, df3, df4

# %%
sj, sn, dj, ds = datepop(time1902, 1)

# %%
ds
# Out:
#      STD_YM   STD_YMD    HDONG_CD HDONG_NM  ...   TMST_20  TMST_21  TMST_22  TMST_23
# 253  201902  20190204  2726051000     범어1동  ...   3349.82  2895.67  1949.47  1304.27
# 254  201902  20190204  2726052000     범어2동  ...   3479.42  2978.39  2033.51  1452.06
# 255  201902  20190204  2726053000     범어3동  ...   2086.02  1698.42  1097.95   736.63
# 256  201902  20190204  2726054000     범어4동  ...   2483.98  2290.92  1697.74  1053.66
# 257  201902  20190204  2726055000     만촌1동  ...   5274.85  4565.14  3411.29  2166.16
# 258  201902  20190204  2726056000     만촌2동  ...   2458.02  2136.90  1540.73  1031.52
# 259  201902  20190204  2726056100     만촌3동  ...   1602.89  1472.52  1059.78   662.51
# 260  201902  20190204  2726057000    수성1가동  ...   2805.13  2598.16  1791.65  1253.29
# 261  201902  20190204  2726058000  수성2.3가동  ...   2606.69  2315.69  1685.05  1138.59
# 262  201902  20190204  2726059000    수성4가동  ...   2658.37  2421.61  1557.38  1100.95
# 263  201902  20190204  2726060100     황금1동  ...   2731.24  2339.90  1757.79  1194.87
# 264  201902  20190204  2726060200     황금2동  ...   2912.68  2621.97  1912.11  1408.44
# 265  201902  20190204  2726061000       중동  ...   1925.31  1637.40  1275.86   861.51
# 266  201902  20190204  2726062000       상동  ...   3438.57  2862.89  1851.20  1356.58
# 267  201902  20190204  2726063000       파동  ...   1946.52  1733.63  1052.13   746.97
# 268  201902  20190204  2726064000      두산동  ...   6614.75  5391.18  3609.24  2577.90
# 269  201902  20190204  2726065100     지산1동  ...   3334.86  2987.27  2310.11  1602.67
# 270  201902  20190204  2726065200     지산2동  ...   1995.11  1653.53  1268.41   899.82
# 271  201902  20190204  2726066100     범물1동  ...   1784.76  1419.87  1078.18   723.61
# 272  201902  20190204  2726066200     범물2동  ...   1291.63  1031.56   771.19   558.52
# 273  201902  20190204  2726067000     고산1동  ...   5348.98  4495.17  3239.32  2074.81
# 274  201902  20190204  2726068000     고산2동  ...  11360.11  9480.74  6590.78  3952.59
# 275  201902  20190204  2726069000     고산3동  ...   2375.17  2205.54  1570.39  1049.01
# 276  201902  20190205  1114052000      소공동  ...   3857.28  3637.25  2741.15  1764.76
#
# [24 rows x 28 columns]

# %%
#데이터프레임을 집어넣으면 그래프로 그려주는 함수
def drawing(df):
  df.iloc[:,4:].T.plot(figsize=(20,10))
  plt.legend(df.iloc[:,3])
  plt.title("Time Flow")
  plt.xlabel("Time")
  plt.ylabel("Number of Population")
  plt.show()

# %%
drawing(sj)

# %%
sj, sn, dj, ds=datepop(time1902, 4)
drawing(sj)

# %%
# 4개 구에 대한 그래프 그리는 함수  
def Drawing(df, day):
  df1= df[69*(day-1):69*(day-1)+15]
  df2= df[69*(day-1)+15:69*(day-1)+34]
  df3= df[69*(day-1)+34:69*(day-1)+46]
  df4= df[69*(day-1)+46:69*(day-1)+69]
  # df_seoul = pd.concat([df1, df2])
  # df_deagu = pd.concat([df3, df4])

  
  df1.iloc[:,4:].T.plot(figsize=(20,10))
  plt.legend(df1.iloc[:,3])
  plt.title("Seoul JungGu")
  plt.xlabel("Time")
  plt.ylabel("Number of Population")
  plt.show()

  df2.iloc[:,4:].T.plot(figsize=(20,10))
  plt.legend(df2.iloc[:,3])
  plt.title("Seoul NowonGu")
  plt.xlabel("Time")
  plt.ylabel("Number of Population")
  plt.show()

  df3.iloc[:,4:].T.plot(figsize=(20,10))
  plt.legend(df3.iloc[:,3])
  plt.title("Deagu JungGu")
  plt.xlabel("Time")
  plt.ylabel("Number of Population")
  plt.show()

  df4.iloc[:,4:].T.plot(figsize=(20,10))
  plt.legend(df4.iloc[:,3])
  plt.title("Deagu SusungGu")
  plt.xlabel("Time")
  plt.ylabel("Number of Population")
  plt.show()

# %%
Drawing(time1902, 20), Drawing(time2002, 20)
# Out:
# (None, None)

# %% [markdown]
# #이런저런 시도

# %%
df0201=time1[time1902['STD_YMD']==20190201]
# df0201['HDONG_CD'][30:]#111, 113, 271, 272
# df0201[df0201['HDONG_CD'][0][:3]==272]
# df0201['HDONG_CD'].str[:3]
#하,,, 이거 왜 안뽑아지지 구별로 묶고싶은데...

# 111-서울중구 시작코드 앞3자리
# 113-노원구 시작코드 앞3자리
# 271-대구중구 시작코드 앞3자리
# 272-대구 수성구 시작코드 앞3자리/

# %%
#19년 2월 1일로 일단 시각화해보자. 동별로 하면 너무 많아서 범례난리나니까 구별로 더해서 하기. 일단 슬라이싱해서 하되, 나중엔 조건문으로 한번에 나누자

# %%
#중구
df_1=df0201[:15]
df_1
# Out:
#     STD_YM   STD_YMD    HDONG_CD HDONG_NM  ...  TMST_20  TMST_21  TMST_22  TMST_23
# 0   201902  20190201  1114052000      소공동  ...  6032.26  6047.05  4806.65  2956.11
# 1   201902  20190201  1114054000      회현동  ...  9800.64  9341.24  6884.91  4034.56
# 2   201902  20190201  1114055000       명동  ...  9797.40  8719.30  7203.45  4845.48
# 3   201902  20190201  1114057000       필동  ...  4464.46  4088.53  3385.14  1746.28
# 4   201902  20190201  1114058000      장충동  ...  2807.25  2626.12  2415.41  1398.94
# 5   201902  20190201  1114059000      광희동  ...  9211.87  8240.86  6349.30  4101.20
# 6   201902  20190201  1114060500     을지로동  ...  4476.52  4499.51  3495.39  2155.01
# 7   201902  20190201  1114061500      신당동  ...  5265.52  4441.36  4602.85  4100.12
# 8   201902  20190201  1114062500      다산동  ...  2690.56  2370.15  2233.59  1481.12
# 9   201902  20190201  1114063500      약수동  ...  3986.07  3449.29  2909.41  2027.42
# 10  201902  20190201  1114064500      청구동  ...  1323.62  1351.79  1200.43   791.47
# 11  201902  20190201  1114065000     신당5동  ...  2050.39  1682.39  1668.51  1085.35
# 12  201902  20190201  1114066500      동화동  ...   913.41   941.16   818.70   545.00
# 14  201902  20190201  1114068000      중림동  ...  2053.21  1948.86  1511.14  1010.18
#
# [15 rows x 28 columns]

# %%
sns.lineplot(x=range(24), y = np.array(timepop1))
sns.lineplot(x=range(24), y = np.array(timepop2))
sns.lineplot(x=range(24), y = np.array(timepop3))
sns.lineplot(x=range(24), y = np.array(timepop4))

# %%
sns.lineplot(x=range(24), y = np.array(timepop1))#중구

# %%
sns.lineplot(x=range(24), y = np.array(timepop2))#노원구

# %%
sns.lineplot(x=range(24), y = np.array(timepop3))#대구중구

# %%
sns.lineplot(x=range(24), y = np.array(timepop4))#대구수성구

# %%
#서울 중구 혼자 뿔이 나있네...
df_1.iloc[:,4:]
# Out:
#     TMST_00  TMST_01  TMST_02  TMST_03  ...  TMST_20  TMST_21  TMST_22  TMST_23
# 0   1496.35  1022.83   706.51   547.77  ...  6032.26  6047.05  4806.65  2956.11
# 1   1692.37  1117.26   839.57   653.41  ...  9800.64  9341.24  6884.91  4034.56
# 2   2226.91  1726.10  1145.43   894.97  ...  9797.40  8719.30  7203.45  4845.48
# 3    698.73   440.70   385.99   275.64  ...  4464.46  4088.53  3385.14  1746.28
# 4    768.34   447.23   429.90   349.46  ...  2807.25  2626.12  2415.41  1398.94
# 5   1617.82  1276.68  1136.34   989.40  ...  9211.87  8240.86  6349.30  4101.20
# 6    641.29   364.04   312.54   312.74  ...  4476.52  4499.51  3495.39  2155.01
# 7   1716.26  1080.77   984.83   893.13  ...  5265.52  4441.36  4602.85  4100.12
# 8    704.38   516.39   363.51   298.83  ...  2690.56  2370.15  2233.59  1481.12
# 9    815.70   511.38   433.95   266.86  ...  3986.07  3449.29  2909.41  2027.42
# 10   328.48   236.89   180.20   121.57  ...  1323.62  1351.79  1200.43   791.47
# 11   494.14   376.47   270.43   259.04  ...  2050.39  1682.39  1668.51  1085.35
# 12   311.31   226.77   171.14   142.67  ...   913.41   941.16   818.70   545.00
# 13   650.76   437.70   317.05   291.12  ...  2495.27  2131.71  2459.41  1548.51
# 14   477.94   367.58   250.94   246.04  ...  2053.21  1948.86  1511.14  1010.18
#
# [15 rows x 24 columns]

# %%
#중구 190201 동별 인구...명동 소공, 회현동에서 사람들 많이 움직이는구나...
df_1.iloc[:,4:].T.plot(figsize=(20,10))
plt.legend(df_1.iloc[:,3])
plt.title("FLOW")
plt.xlabel("Time")
plt.ylabel("Number of Population")
plt.show()

# %%
df_2.iloc[:,4:].T.plot(figsize=(20,10))
plt.legend(df_2.iloc[:,3])
plt.title("FLOW")
plt.xlabel("Time")
plt.ylabel("Number of Population")
plt.show()

# %%
df_3.iloc[:,4:].T.plot(figsize=(20,10))
plt.legend(df_3.iloc[:,3])
plt.title("FLOW")
plt.xlabel("Time")
plt.ylabel("Number of Population")
plt.show()

# %%
df_4.iloc[:,4:].T.plot(figsize=(20,10))
plt.legend(df_4.iloc[:,3])
plt.title("FLOW")
plt.xlabel("Time")
plt.ylabel("Number of Population")
plt.show()
