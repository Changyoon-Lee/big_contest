# %%
import pandas as pd
import matplotlib
import matplotlib.font_manager as fm
font_location = 'C:/Windows/Fonts/SeoulNamsanEB.ttf' # For Windows
font_name = fm.FontProperties(fname=font_location).get_name()
matplotlib.rc('font', family=font_name)

# %% [markdown]
# # 지하철역, 버스 정류장 데이터

# %%
# 버스 이용정보
pd.read_csv('2020년_버스노선별_정류장별_시간대별_승하차_인원_정보(03월).csv', encoding='cp949' )
pd.read_csv('2020년_버스노선별_정류장별_시간대별_승하차_인원_정보(04월).csv', encoding='cp949' )
pd.read_csv('2020년_버스노선별_정류장별_시간대별_승하차_인원_정보(05월).csv', encoding='cp949' )
# Out:
#          사용년월      노선ID  노선번호              노선명 버스정류장ARS번호         역ID   역명  \
# 0      202005  11110001   100   100번(하계동~용산구청)      01003   명륜3가.성대입구    0
# 1      202005  11110001   100   100번(하계동~용산구청)      02156  을지로입구.로얄호텔  180
# 2      202005  11110001   100   100번(하계동~용산구청)      03267     서빙고역교차로    0
# 3      202005  11110001   100   100번(하계동~용산구청)      01198         원남동    0
# 4      202005  11110001   100   100번(하계동~용산구청)      11452     하계극동아파트    0
# ...       ...       ...   ...              ...        ...         ...  ...
# 39074  202005  91000034  9714  9714번(교하운정~서울역)      35637   행신초등학교(중)    9
# 39075  202005  91000034  9714  9714번(교하운정~서울역)      35632     서정마을(중)    2
# 39076  202005  91000034  9714  9714번(교하운정~서울역)      35633      행신동(중)    2
# 39077  202005  91000034  9714  9714번(교하운정~서울역)      63655        청석마을    7
# 39078  202005  91000034  9714  9714번(교하운정~서울역)      13012        연세대앞    0
#
# ...

# %%
# 일별 지하철 이용정보
sub_03 = pd.read_csv('CARD_SUBWAY_MONTH_202003.csv', encoding='cp949')
sub_04 = pd.read_csv('CARD_SUBWAY_MONTH_202004.csv', encoding='cp949')

# %%
sub_03
# Out:
#            사용일자       노선명          역명   승차총승객수   하차총승객수      등록일자
# 0      20200301  공항철도 1호선          운서   3621.0   3795.0  20200304
# 1      20200301     우이신설선         신설동    636.0    646.0  20200304
# 2      20200301     우이신설선          보문    564.0    542.0  20200304
# 3      20200301     우이신설선  성신여대입구(돈암)   1170.0   1388.0  20200304
# 4      20200301     우이신설선          정릉   1454.0   1253.0  20200304
# ...         ...       ...         ...      ...      ...       ...
# 18260  20200331  9호선2~3단계         봉은사  11506.0  11670.0  20200403
# 18261  20200331  9호선2~3단계       종합운동장   3252.0   3232.0  20200403
# 18262  20200331  9호선2~3단계          삼전   5226.0   5149.0  20200403
# 18263  20200331  9호선2~3단계        석촌고분   4394.0   4382.0  20200403
# 18264  20200331  9호선2~3단계          석촌   5935.0   5241.0  20200403
#
# [18265 rows x 6 columns]

# %%
# 역별 시간대별 승하차 인원정보
sub_data = pd.read_csv('서울시 지하철 호선별 역별 시간대별 승하차 인원 정보.csv', encoding='cp949')

# %% [markdown]
# # 유동인구 데이터

# %%
what= pd.read_csv(r'C:\Users\sb\TIL\TIL\01_유동인구데이터(SK텔레콤)\4개지역_FLOW_TIME_201902.CSV', sep = '|')

# %%
time1902= pd.read_csv(r'C:\Users\sb\TIL\TIL\01_유동인구데이터(SK텔레콤)\4개지역_FLOW_TIME_201902.CSV', sep = '|')
time1903= pd.read_csv(r'C:\Users\sb\TIL\TIL\01_유동인구데이터(SK텔레콤)\4개지역_FLOW_TIME_201903.CSV', sep = '|')
time1904= pd.read_csv(r'C:\Users\sb\TIL\TIL\01_유동인구데이터(SK텔레콤)\4개지역_FLOW_TIME_201904.CSV', sep = '|')
time1905= pd.read_csv(r'C:\Users\sb\TIL\TIL\01_유동인구데이터(SK텔레콤)\4개지역_FLOW_TIME_201905.CSV', sep = '|')
time2002= pd.read_csv(r'C:\Users\sb\TIL\TIL\01_유동인구데이터(SK텔레콤)\4개지역_FLOW_TIME_202002.CSV', sep = '|')
time2003= pd.read_csv(r'C:\Users\sb\TIL\TIL\01_유동인구데이터(SK텔레콤)\4개지역_FLOW_TIME_202003.CSV', sep = '|')
time2004= pd.read_csv(r'C:\Users\sb\TIL\TIL\01_유동인구데이터(SK텔레콤)\4개지역_FLOW_TIME_202004.CSV', sep = '|')
time2005= pd.read_csv(r'C:\Users\sb\TIL\TIL\01_유동인구데이터(SK텔레콤)\4개지역_FLOW_TIME_202005.CSV', sep = '|')

# %% [markdown]
# # 지정 지역 정보

# %%
Seoul_junggu = ['서대문', '충정로', '시청', '회현', '서울역', '을지로입구', '명동', '을지로3가', '을지로4가', '충무로', '동대입구', '약수', '버티고개', '청구', '신당', '동대문역사문화공원', ]

# %%
Seoul_nowon = ['수락산', '마들', '노원', '중계', '하계', '월계', '광운대', '석계', '태릉입구', '화랑대', '공릉', '상계', '당고개']\

# %% [markdown]
# # 서울 중구 지하철역 데이터

# %%
df = sub_data[sub_data['지하철역'] == '서대문']

# %%
df
# Out:
#           사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  \
# 146    202007  5호선  서대문             2             0          2753
# 744    202006  5호선  서대문            11             0          2620
# 1344   202005  5호선  서대문            10             0          2472
# 1941   202004  5호선  서대문             8             0          2559
# 2540   202003  5호선  서대문            15             1          2383
# ...       ...  ...  ...           ...           ...           ...
# 36069  201505  5호선  서대문             3             0          3239
# 36625  201504  5호선  서대문             6             0          2995
# 37179  201503  5호선  서대문             4             0          2891
# 37733  201502  5호선  서대문             0             0          2231
# 38283  201501  5호선  서대문             5             0          2465
#
#        05시-06시 하차인원  06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  \
# 146            1309          6010         13778         17861  ...
# ...

# %%
df1 = pd.concat([df, sub_data[sub_data['지하철역'] == '충정로']], axis=0)

# %%
df1
# Out:
#           사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  \
# 146    202007  5호선  서대문             2             0          2753
# 744    202006  5호선  서대문            11             0          2620
# 1344   202005  5호선  서대문            10             0          2472
# 1941   202004  5호선  서대문             8             0          2559
# 2540   202003  5호선  서대문            15             1          2383
# ...       ...  ...  ...           ...           ...           ...
# 37201  201503  5호선  충정로             2             0          1426
# 37643  201502  2호선  충정로            25             2          3620
# 37755  201502  5호선  충정로             2             0          1139
# 38193  201501  2호선  충정로            34             1          4186
# 38305  201501  5호선  충정로             3             0          1347
#
#        05시-06시 하차인원  06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  \
# 146            1309          6010         13778         17861  ...
# ...

# %%
df
# Out:
#           사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  \
# 146    202007  5호선  서대문             2             0          2753
# 744    202006  5호선  서대문            11             0          2620
# 1344   202005  5호선  서대문            10             0          2472
# 1941   202004  5호선  서대문             8             0          2559
# 2540   202003  5호선  서대문            15             1          2383
# ...       ...  ...  ...           ...           ...           ...
# 36069  201505  5호선  서대문             3             0          3239
# 36625  201504  5호선  서대문             6             0          2995
# 37179  201503  5호선  서대문             4             0          2891
# 37733  201502  5호선  서대문             0             0          2231
# 38283  201501  5호선  서대문             5             0          2465
#
#        05시-06시 하차인원  06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  \
# 146            1309          6010         13778         17861  ...
# ...

# %%
for station in Seoul_junggu[1:]:
     df = pd.concat([df, sub_data[sub_data['지하철역'] == station]], axis=0)

# %%
Seoul_junggu_data = df

# %%
#date time으로 날짜 형식 변경
Seoul_junggu_data['사용월'] = pd.to_datetime(Seoul_junggu_data['사용월'], format = '%Y%m', errors='ignore')

# %%
Seoul_junggu_data
# Out:
#              사용월  호선명       지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  \
# 146   2020-07-01  5호선        서대문             2             0          2753
# 744   2020-06-01  5호선        서대문            11             0          2620
# 1344  2020-05-01  5호선        서대문            10             0          2472
# 1941  2020-04-01  5호선        서대문             8             0          2559
# 2540  2020-03-01  5호선        서대문            15             1          2383
# ...          ...  ...        ...           ...           ...           ...
# 37686 2015-02-01  4호선  동대문역사문화공원           139             4          7075
# 37721 2015-02-01  5호선  동대문역사문화공원             0             0           171
# 38157 2015-01-01  2호선  동대문역사문화공원           221             4         10861
# 38236 2015-01-01  4호선  동대문역사문화공원           195             2          9289
# 38271 2015-01-01  5호선  동대문역사문화공원             0             0           178
#
# ...

# %% [markdown]
# # 서울 노원구 지하철역 데이터

# %%
df2 =  sub_data[sub_data['지하철역'] == '수락산']

# %%
df2
# Out:
#           사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  \
# 240    202007  7호선  수락산            16             1          9371
# 838    202006  7호선  수락산            16             1          9329
# 1438   202005  7호선  수락산            15             1          8529
# 2035   202004  7호선  수락산            12             0          7923
# 2634   202003  7호선  수락산            32             1          7918
# ...       ...  ...  ...           ...           ...           ...
# 36162  201505  7호선  수락산            27             0         10352
# 36718  201504  7호선  수락산            23             0          9713
# 37272  201503  7호선  수락산             9             0          9707
# 37826  201502  7호선  수락산            15             1          7590
# 38376  201501  7호선  수락산            20             1          8917
#
#        05시-06시 하차인원  06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  \
# 240             874         22147          5765         53172  ...
# ...

# %%
for station in Seoul_nowon[1:]:
     df2 = pd.concat([df2, sub_data[sub_data['지하철역'] == station]], axis=0)

# %%
Seoul_nowon_data = df2

# %%
Seoul_nowon_data
# Out:
#           사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  \
# 240    202007  7호선  수락산            16             1          9371
# 838    202006  7호선  수락산            16             1          9329
# 1438   202005  7호선  수락산            15             1          8529
# 2035   202004  7호선  수락산            12             0          7923
# 2634   202003  7호선  수락산            32             1          7918
# ...       ...  ...  ...           ...           ...           ...
# 36020  201505  4호선  당고개            61             0         10749
# 36576  201504  4호선  당고개            73             1         10265
# 37130  201503  4호선  당고개            60             2          9784
# 37684  201502  4호선  당고개            40             1          7709
# 38234  201501  4호선  당고개            44             2          9100
#
#        05시-06시 하차인원  06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  \
# 240             874         22147          5765         53172  ...
# ...

# %%
Seoul_nowon_data['사용월'] = pd.to_datetime(Seoul_nowon_data['사용월'], format = '%Y%m', errors='ignore')

# %%
Seoul_nowon_data.set_index('사용월', inplace=True)
Seoul_nowon_data.drop('작업일자', axis=1, inplace=True)

# %%
Seoul_junggu_data.set_index('사용월', inplace=True)
Seoul_junggu_data.drop('작업일자', axis=1, inplace=True)

# %%
import copy
#데이터 백업
Seoul_junggu_backup = copy.deepcopy(Seoul_junggu_data)
Seoul_nowon_backup = copy.deepcopy(Seoul_nowon_data)

# %%
Seoul_junggu_data.columns
# Out:
# Index(['호선명', '지하철역', '04시-05시 승차인원', '04시-05시 하차인원', '05시-06시 승차인원',
#        '05시-06시 하차인원', '06시-07시 승차인원', '06시-07시 하차인원', '07시-08시 승차인원',
#        '07시-08시 하차인원', '08시-09시 승차인원', '08시-09시 하차인원', '09시-10시 승차인원',
#        '09시-10시 하차인원', '10시-11시 승차인원', '10시-11시 하차인원', '11시-12시 승차인원',
#        '11시-12시 하차인원', '12시-13시 승차인원', '12시-13시 하차인원', '13시-14시 승차인원',
#        '13시-14시 하차인원', '14시-15시 승차인원', '14시-15시 하차인원', '15시-16시 승차인원',
#        '15시-16시 하차인원', '16시-17시 승차인원', '16시-17시 하차인원', '17시-18시 승차인원',
#        '17시-18시 하차인원', '18시-19시 승차인원', '18시-19시 하차인원', '19시-20시 승차인원',
#        '19시-20시 하차인원', '20시-21시 승차인원', '20시-21시 하차인원', '21시-22시 승차인원',
#        '21시-22시 하차인원', '22시-23시 승차인원', '22시-23시 하차인원', '23시-24시 승차인원',
#        '23시-24시 하차인원', '00시-01시 승차인원', '00시-01시 하차인원', '01시-02시 승차인원',
#        '01시-02시 하차인원', '02시-03시 승차인원', '02시-03시 하차인원', '03시-04시 승차인원',
#        '03시-04시 하차인원'],
#       dtype='object')

# %% [markdown]
# # 중구, 노원지역 데이터 지정 월별 산출

# %%
# 승차인원, 하차인원 구분
up, down = [], []

for column in Seoul_junggu_data.columns:
    if '승차인원' in column:
        up.append(column)
    elif '하차인원' in column:
        down.append(column)

up[:3], down[:3]
# Out:
# (['04시-05시 승차인원', '05시-06시 승차인원', '06시-07시 승차인원'],
#  ['04시-05시 하차인원', '05시-06시 하차인원', '06시-07시 하차인원'])

# %%
Seoul_all =pd.concat([Seoul_junggu_data, Seoul_nowon_data], axis=0)

# %%
Seoul_all
# Out:
#             호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  05시-06시 하차인원  \
# 사용월
# 2020-07-01  5호선  서대문             2             0          2753          1309
# 2020-06-01  5호선  서대문            11             0          2620          1416
# 2020-05-01  5호선  서대문            10             0          2472          1222
# 2020-04-01  5호선  서대문             8             0          2559          1278
# 2020-03-01  5호선  서대문            15             1          2383          1261
# ...         ...  ...           ...           ...           ...           ...
# 2015-05-01  4호선  당고개            61             0         10749            15
# 2015-04-01  4호선  당고개            73             1         10265            13
# 2015-03-01  4호선  당고개            60             2          9784             9
# 2015-02-01  4호선  당고개            40             1          7709            14
# 2015-01-01  4호선  당고개            44             2          9100            14
#
# ...

# %%
def find_passengers(station, month, status):
    df = Seoul_all.loc['2020-{}-01'.format(month)]
    if status == '승차': 
        df[df['지하철역'] == station][up].sum().plot(figsize=(10,15))
    elif status == '하차':
        df[df['지하철역'] == station][down].sum().plot(figsize=(10,15))

find_passengers('서울역', 2, '승차')

# %% [markdown]
# # 유동인구 데이터와 연결
# - 전체 평균 / 주말 평균/ 주중평균

# %%
time2002.rename({'STD_YM':'기준년도', 'STD_YMD':'기준연월일', 'HDONG_CD':'행정동코드', 'HDONG_NM':'행정동명칭'}, axis='columns', inplace=True)

# %%
test = time2002

# %%
time_column = []
for column in test.columns:
    if 'TMST' in column:
        time_column.append(column)

# %%
test[test['행정동명칭'] == '명동'][time_column].sum().plot(figsize=(20,10))

# %% [markdown]
# # 유동인구데이터와 지하철의 형식이 맞지 않는다
# - 지하철의 경우는 새벽 4시-5시부터 그 다음날 새벽 1시-2시인데

# %%
def find_passengers_modified(station, month, status):
    df = Seoul_all.loc['2020-{}-01'.format(month)]
    if status == '승차': 
        df[df['지하철역'] == station][up[:-4]].sum().plot(figsize=(10,10))
    elif status == '하차':
        df[df['지하철역'] == station][down[:-4]].sum().plot(figsize=(10,10))

# %%
test
# Out:
#         기준년도     기준연월일       행정동코드 행정동명칭  TMST_00  TMST_01  TMST_02  TMST_03  \
# 0     202002  20200201  1114052000   소공동  1393.34  1144.91   900.51   721.78
# 1     202002  20200201  1114054000   회현동  1586.96  1170.81   898.06   682.55
# 2     202002  20200201  1114055000    명동  1534.52  1139.65  1015.20   799.85
# 3     202002  20200201  1114057000    필동  1321.52   933.49   803.40   690.18
# 4     202002  20200201  1114058000   장충동   629.17   561.68   454.77   372.22
# ...      ...       ...         ...   ...      ...      ...      ...      ...
# 1996  202002  20200229  2726066100  범물1동   485.96   388.68   348.90   289.15
# 1997  202002  20200229  2726066200  범물2동   947.07   896.23   851.62   794.46
# 1998  202002  20200229  2726067000  고산1동  2162.60  1758.41  1318.00  1203.27
# 1999  202002  20200229  2726068000  고산2동  2599.19  2085.08  1549.93  1509.08
# 2000  202002  20200229  2726069000  고산3동   953.12   774.17   597.53   535.36
#
# ...

# %%
test[test['행정동명칭'] == '명동'][time_column[4:]].sum().plot(figsize=(10,10))

# %% [markdown]
# # 일자별 지하철 데이터

# %%
df = pd.read_csv(r'C:\Users\sb\TIL\TIL\빅콘\역별 일별 지하철.csv')

# %%
df
# Out:
#                날짜   호선   역번호                역명  구분  06시 이전  06 ~ 07  07 ~ 08  \
# 0      2020-01-01  1호선   150               서울역  하차     235      952      828
# 1      2020-01-01  1호선   151                시청  하차      81      223      334
# 2      2020-01-01  1호선   152                종각  하차      71      191      295
# 3      2020-01-01  1호선   153              종로3가  하차      53      147      190
# 4      2020-01-01  1호선   154              종로5가  하차      22      124      170
# ...           ...  ...   ...               ...  ..     ...      ...      ...
# 41873  2020-05-31  8호선  2823  남한산성입구(성남법원.검찰청)  하차      30       80      102
# 41874  2020-05-31  8호선  2824             단대오거리  하차      42      101      124
# 41875  2020-05-31  8호선  2825                신흥  하차      13       51       42
# 41876  2020-05-31  8호선  2826                수진  하차      15       48       35
# 41877  2020-05-31  8호선  2827                모란  하차      19       55       56
#
# ...

# %% [markdown]
# # 승차 데이터

# %%
up_data =pd.read_csv(r'C:\Users\sb\TIL\TIL\빅콘\역별 일별 지하철 승차.csv')

# %%
up_data['날짜'] = pd.to_datetime(up_data['날짜'])

# %%
up_data.set_index('날짜', inplace= True)

# %%
time_col = list(up_data.columns) 
time_col.remove('호선')
time_col.remove('역번호')
time_col.remove('구분')
time_col.remove('합 계')
time_col.remove('역명')

# %%
up_data[time_col]
# Out:
#             06시 이전  06 ~ 07  07 ~ 08  08 ~ 09  09 ~ 10  10 ~ 11  11 ~ 12  \
# 날짜
# 2020-01-01     356      280      313      774      923     1418     2288
# 2020-01-01     105      118      123      206      318      309      442
# 2020-01-01     798      366      198      236      310      379      666
# 2020-01-01     338      189      153      198      311      466      673
# 2020-01-01      60       50       67      143      228      368      626
# ...            ...      ...      ...      ...      ...      ...      ...
# 2020-05-31     149      190      290      508      537      500      462
# 2020-05-31     133      146      244      321      411      380      319
# 2020-05-31      75       70      114      143      174      160      131
# 2020-05-31      55       76      116      179      202      160      171
# 2020-05-31      55       48       83      108      127      166      138
#
#             12 ~ 13  13 ~ 14  14 ~ 15  15 ~ 16  16 ~ 17  17 ~ 18  18 ~ 19  \
# 날짜
# ...

# %%
def find_up(station, date):
    if len(up_data[up_data['역명'] == station].loc[date][time_col]) == 20:
        up_data[up_data['역명'] == station].loc[date][time_col].plot(figsize=(20,10))
    else:
        up_data[up_data['역명'] == station].loc[date][time_col].sum().plot(figsize=(20,10))

find_up('명동', '2020-02-01')

# %% [markdown]
# # 하차 데이터

# %%
df['날짜'] = pd.to_datetime(df['날짜'])
df.set_index('날짜', inplace=True)

down_data = df[df['구분'] == '하차']

# %%
def find_down(station, date):
    if len(down_data[down_data['역명'] == station].loc[date][time_col]) == 20:
        down_data[down_data['역명'] == station].loc[date][time_col].plot(figsize=(20,10))
    else:
        down_data[down_data['역명'] == station].loc[date][time_col].sum().plot(figsize=(20,10))

find_down('명동', '2020-02-01')

# %%
test[test['행정동명칭'] == '명동'][time_column[5:]].iloc[0].plot(figsize=(20,10))

# %% [markdown]
# # 상관관계 구하기

# %% [markdown]
# ## 승차인구 데이터

# %%
up_data
# Out:
#              호선   역번호                역명  구분  06시 이전  06 ~ 07  07 ~ 08  \
# 날짜
# 2020-01-01  1호선   150               서울역  승차     356      280      313
# 2020-01-01  1호선   151                시청  승차     105      118      123
# 2020-01-01  1호선   152                종각  승차     798      366      198
# 2020-01-01  1호선   153              종로3가  승차     338      189      153
# 2020-01-01  1호선   154              종로5가  승차      60       50       67
# ...         ...   ...               ...  ..     ...      ...      ...
# 2020-05-31  8호선  2823  남한산성입구(성남법원.검찰청)  승차     149      190      290
# 2020-05-31  8호선  2824             단대오거리  승차     133      146      244
# 2020-05-31  8호선  2825                신흥  승차      75       70      114
# 2020-05-31  8호선  2826                수진  승차      55       76      116
# 2020-05-31  8호선  2827                모란  승차      55       48       83
#
#             08 ~ 09  09 ~ 10  10 ~ 11  ...  16 ~ 17  17 ~ 18  18 ~ 19  \
# 날짜                                     ...
# ...

# %%
up_data

def ride_pop(station, date):
    if len(up_data[up_data['역명'] == station].loc[date][time_col]) == 20:
        riding_pop = up_data[up_data['역명'] == station].loc[date][time_col][:-1].astype(float)
        return riding_pop
    else:
        riding_pop_all = up_data[up_data['역명'] == station].loc[date][time_col][:-1].sum().astype(float)
        return riding_pop_all

ride_pop('명동', '2020-02-01')
# Out:
# 06시 이전       30.0
# 06 ~ 07      85.0
# 07 ~ 08     177.0
# 08 ~ 09     322.0
# 09 ~ 10     758.0
# 10 ~ 11     907.0
# 11 ~ 12    1200.0
# 12 ~ 13    1152.0
# 13 ~ 14    1254.0
# 14 ~ 15    1280.0
# 15 ~ 16    1532.0
# 16 ~ 17    1780.0
# 17 ~ 18    1948.0
# 18 ~ 19    2023.0
# 19 ~ 20    1799.0
# 20 ~ 21    1680.0
# 21 ~ 22    1808.0
# 22 ~ 23    1842.0
# 23 ~ 24     807.0
# Name: 2020-02-01 00:00:00, dtype: float64

# %%
up_data

def ride_pop(station, date):
    if len(up_data[up_data['역명'] == station].loc[date][time_col]) == 20:
        riding_pop = up_data[up_data['역명'] == station].loc[date][time_col][:-1].astype(float)
        return riding_pop
    else:
        riding_pop_all = up_data[up_data['역명'] == station].loc[date][time_col][:-1].sum().astype(float)
        return riding_pop_all

ride_pop('명동', '2020-02-01')

a_ = up_data[up_data['역명'] == '명동'].loc['2020-02-01'][time_col][:-1]

# %%
up_data

def ride_pop(station, date):
    if len(up_data[up_data['역명'] == station].loc[date][time_col]) == 20:
        riding_pop = up_data[up_data['역명'] == station].loc[date][time_col][:-1].astype(float)
        return riding_pop
    else:
        riding_pop_all = up_data[up_data['역명'] == station].loc[date][time_col][:-1].sum().astype(float)
        return riding_pop_all

ride_pop('명동', '2020-02-01')

a_ = up_data[up_data['역명'] == '명동'].loc['2020-02-01'][time_col][:-1]

df_1_ = pd.DataFrame(a_)

# %%
up_data

def ride_pop(station, date):
    if len(up_data[up_data['역명'] == station].loc[date][time_col]) == 20:
        riding_pop = up_data[up_data['역명'] == station].loc[date][time_col][:-1].astype(float)
        return riding_pop
    else:
        riding_pop_all = up_data[up_data['역명'] == station].loc[date][time_col][:-1].sum().astype(float)
        return riding_pop_all

ride_pop('명동', '2020-02-01')

a_ = up_data[up_data['역명'] == '명동'].loc['2020-02-01'][time_col][:-1]

df_1_ = pd.DataFrame(a_)

df_1_.columns = ['지하철승차인구']

# %%
up_data

def ride_pop(station, date):
    if len(up_data[up_data['역명'] == station].loc[date][time_col]) == 20:
        riding_pop = up_data[up_data['역명'] == station].loc[date][time_col][:-1].astype(float)
        return riding_pop
    else:
        riding_pop_all = up_data[up_data['역명'] == station].loc[date][time_col][:-1].sum().astype(float)
        return riding_pop_all

ride_pop('명동', '2020-02-01')

a_ = up_data[up_data['역명'] == '명동'].loc['2020-02-01'][time_col][:-1]

df_1_ = pd.DataFrame(a_)

df_1_.columns = ['지하철승차인구']

df_1_['지하철승차인구'].astype(float)
# Out:
# 06시 이전       30.0
# 06 ~ 07      85.0
# 07 ~ 08     177.0
# 08 ~ 09     322.0
# 09 ~ 10     758.0
# 10 ~ 11     907.0
# 11 ~ 12    1200.0
# 12 ~ 13    1152.0
# 13 ~ 14    1254.0
# 14 ~ 15    1280.0
# 15 ~ 16    1532.0
# 16 ~ 17    1780.0
# 17 ~ 18    1948.0
# 18 ~ 19    2023.0
# 19 ~ 20    1799.0
# 20 ~ 21    1680.0
# 21 ~ 22    1808.0
# 22 ~ 23    1842.0
# 23 ~ 24     807.0
# Name: 지하철승차인구, dtype: float64

# %%
up_data

def ride_pop(station, date):
    if len(up_data[up_data['역명'] == station].loc[date][time_col]) == 20:
        riding_pop = up_data[up_data['역명'] == station].loc[date][time_col][:-1].astype(float)
        return riding_pop
    else:
        riding_pop_all = up_data[up_data['역명'] == station].loc[date][time_col][:-1].sum().astype(float)
        return riding_pop_all

ride_pop('명동', '2020-02-01')

a_ = up_data[up_data['역명'] == '명동'].loc['2020-02-01'][time_col][:-1]

df_1_ = pd.DataFrame(a_)

df_1_.columns = ['지하철승차인구']

df_1_['지하철승차인구'].astype(float)

df_1_.reset_index(inplace=True)

# %%
up_data

def ride_pop(station, date):
    if len(up_data[up_data['역명'] == station].loc[date][time_col]) == 20:
        riding_pop = up_data[up_data['역명'] == station].loc[date][time_col][:-1].astype(float)
        return riding_pop
    else:
        riding_pop_all = up_data[up_data['역명'] == station].loc[date][time_col][:-1].sum().astype(float)
        return riding_pop_all

ride_pop('명동', '2020-02-01')

a_ = up_data[up_data['역명'] == '명동'].loc['2020-02-01'][time_col][:-1]

df_1_ = pd.DataFrame(a_)

df_1_.columns = ['지하철승차인구']

df_1_['지하철승차인구'].astype(float)

df_1_.reset_index(inplace=True)

df_1_['행정동인구'] = df_2[2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-02b843ab857d> in <module>
# ----> 1 df_1_['행정동인구'] = df_2[2]
#
# NameError: name 'df_2' is not defined

# %%
up_data

def ride_pop(station, date):
    if len(up_data[up_data['역명'] == station].loc[date][time_col]) == 20:
        riding_pop = up_data[up_data['역명'] == station].loc[date][time_col][:-1].astype(float)
        return riding_pop
    else:
        riding_pop_all = up_data[up_data['역명'] == station].loc[date][time_col][:-1].sum().astype(float)
        return riding_pop_all

ride_pop('명동', '2020-02-01')

a_ = up_data[up_data['역명'] == '명동'].loc['2020-02-01'][time_col][:-1]

df_1_ = pd.DataFrame(a_)

df_1_.columns = ['지하철승차인구']

df_1_['지하철승차인구'].astype(float)

df_1_.reset_index(inplace=True)

df_1_['행정동인구'] = df_2[2]

df_1_['지하철승차인구'] = df_1_['지하철승차인구'].astype(float)

# %%
up_data

def ride_pop(station, date):
    if len(up_data[up_data['역명'] == station].loc[date][time_col]) == 20:
        riding_pop = up_data[up_data['역명'] == station].loc[date][time_col][:-1].astype(float)
        return riding_pop
    else:
        riding_pop_all = up_data[up_data['역명'] == station].loc[date][time_col][:-1].sum().astype(float)
        return riding_pop_all

ride_pop('명동', '2020-02-01')

a_ = up_data[up_data['역명'] == '명동'].loc['2020-02-01'][time_col][:-1]

df_1_ = pd.DataFrame(a_)

df_1_.columns = ['지하철승차인구']

df_1_['지하철승차인구'].astype(float)

df_1_.reset_index(inplace=True)

df_1_['행정동인구'] = df_2[2]

df_1_['지하철승차인구'] = df_1_['지하철승차인구'].astype(float)

df_1_.set_index('index', inplace=True)

# %%
# Out:
#          지하철승차인구
# 지하철승차인구      1.0

# %% [markdown]
# ## 하차인구 데이터

# %%
def quit_pop(station, date):
    if len(down_data[down_data['역명'] == station].loc[date][time_col]) == 20:
        riding_pop = down_data[down_data['역명'] == station].loc[date][time_col][:-1].astype(float)
        return riding_pop
    else:
        riding_pop_all = down_data[down_data['역명'] == station].loc[date][time_col][:-1].sum().astype(float)
        return riding_pop_all

quit_pop('명동', '2020-02-01')
# Out:
# 06시 이전       40.0
# 06 ~ 07     367.0
# 07 ~ 08     673.0
# 08 ~ 09    1125.0
# 09 ~ 10    1691.0
# 10 ~ 11    1543.0
# 11 ~ 12    1555.0
# 12 ~ 13    1725.0
# 13 ~ 14    1875.0
# 14 ~ 15    1729.0
# 15 ~ 16    1895.0
# 16 ~ 17    1889.0
# 17 ~ 18    1980.0
# 18 ~ 19    1735.0
# 19 ~ 20    1415.0
# 20 ~ 21    1096.0
# 21 ~ 22     934.0
# 22 ~ 23     577.0
# 23 ~ 24     288.0
# Name: 2020-02-01 00:00:00, dtype: float64

# %%
b
# Out:
# TMST_05     1506.43
# TMST_06     3603.61
# TMST_07     4707.65
# TMST_08     7198.98
# TMST_09     9182.75
# TMST_10     9864.41
# TMST_11    10970.79
# TMST_12    11471.71
# TMST_13    11221.18
# TMST_14    11188.64
# TMST_15    10109.60
# TMST_16    10587.30
# TMST_17    10697.87
# TMST_18     8781.11
# TMST_19     6420.97
# TMST_20     5091.03
# TMST_21     5025.40
# TMST_22     4415.18
# TMST_23     3415.71
# Name: 2, dtype: float64

# %%
a = down_data[down_data['역명'] == station].loc['2020-02-01'][time_col][:-1]
b = test[test['행정동명칭'] == '명동'][time_column[5:]].iloc[0]

df_1 = pd.DataFrame(a)
df_2 = pd.DataFrame(b)

df_1['행정동인구'] = b
df_1.reset_index(inplace = True)
df_1.columns = ['시간', '지하철인구', '행정동인구']

df_1.set_index('시간', inplace=True)
df_2.reset_index(inplace=True)

df_1['행정동인구'] = df_2[2]

# %%
df_1
# Out:
#          시간  지하철인구     행정동인구
# 0    06시 이전    7.0   1506.43
# 1   06 ~ 07  252.0   3603.61
# 2   07 ~ 08  208.0   4707.65
# 3   08 ~ 09  350.0   7198.98
# 4   09 ~ 10  583.0   9182.75
# 5   10 ~ 11  491.0   9864.41
# 6   11 ~ 12  468.0  10970.79
# 7   12 ~ 13  545.0  11471.71
# 8   13 ~ 14  481.0  11221.18
# 9   14 ~ 15  526.0  11188.64
# 10  15 ~ 16  622.0  10109.60
# 11  16 ~ 17  632.0  10587.30
# 12  17 ~ 18  810.0  10697.87
# 13  18 ~ 19  882.0   8781.11
# 14  19 ~ 20  607.0   6420.97
# 15  20 ~ 21  619.0   5091.03
# 16  21 ~ 22  670.0   5025.40
# 17  22 ~ 23  602.0   4415.18
# 18  23 ~ 24  489.0   3415.71

# %%
df_1.reset_index(inplace=True)

# %%
frames = [df_1, df_2]
result= pd.concat(frames, axis=1)

# %%
df_1['지하철인구'] = df_1['지하철인구'].astype(float)

# %%
df_1
# Out:
#          시간  지하철인구  행정동인구
# 0    06시 이전    7.0    NaN
# 1   06 ~ 07  252.0    NaN
# 2   07 ~ 08  208.0    NaN
# 3   08 ~ 09  350.0    NaN
# 4   09 ~ 10  583.0    NaN
# 5   10 ~ 11  491.0    NaN
# 6   11 ~ 12  468.0    NaN
# 7   12 ~ 13  545.0    NaN
# 8   13 ~ 14  481.0    NaN
# 9   14 ~ 15  526.0    NaN
# 10  15 ~ 16  622.0    NaN
# 11  16 ~ 17  632.0    NaN
# 12  17 ~ 18  810.0    NaN
# 13  18 ~ 19  882.0    NaN
# 14  19 ~ 20  607.0    NaN
# 15  20 ~ 21  619.0    NaN
# 16  21 ~ 22  670.0    NaN
# 17  22 ~ 23  602.0    NaN
# 18  23 ~ 24  489.0    NaN

# %%
df_1.corr()
# Out:
#        지하철인구  행정동인구
# 지하철인구    1.0    NaN
# 행정동인구    NaN    NaN

# %% [markdown]
# # 승차 인구 데이터

# %%
def ride_pop(station, date):
    if len(up_data[up_data['역명'] == station].loc[date][time_col]) == 20:
        riding_pop = up_data[up_data['역명'] == station].loc[date][time_col][:-1].astype(float)
        return riding_pop
    else:
        riding_pop_all = up_data[up_data['역명'] == station].loc[date][time_col][:-1].sum().astype(float)
        return riding_pop_all

ride_pop('명동', '2020-02-01')

a_ = up_data[up_data['역명'] == '명동'].loc['2020-02-01'][time_col][:-1]
df_1_ = pd.DataFrame(a_)
df_1_.columns = ['지하철승차인구']
df_1_['지하철승차인구'] = df_1_['지하철승차인구'].astype(float)
df_1_.reset_index(inplace=True)
df_1_['행정동인구'] = df_2[2]
df_1_.set_index('index', inplace=True)
df_1_.corr()
# Out:
#           지하철승차인구     행정동인구
# 지하철승차인구  1.000000  0.408375
# 행정동인구    0.408375  1.000000

# %% [markdown]
# ## 승차하차인원 모두 고려

# %%
df_1.columns = ['시간', '지하철하차인구', '행정동인구']

# %%
df_1_.reset_index(inplace=True)

# %%
a = down_data[down_data['역명'] == station].loc['2020-02-01'][time_col][:-1]

b = test[test['행정동명칭'] == '명동'][time_column[5:]].iloc[0]

# %%
a = down_data[down_data['역명'] == station].loc['2020-02-01'][time_col][:-1]

b = test[test['행정동명칭'] == '명동'][time_column[5:]].iloc[0]

df_1 = pd.DataFrame(a)

# %%
a = down_data[down_data['역명'] == station].loc['2020-02-01'][time_col][:-1]

b = test[test['행정동명칭'] == '명동'][time_column[5:]].iloc[0]

df_1 = pd.DataFrame(a)

df_2 = pd.DataFrame(b)

# %%
a = down_data[down_data['역명'] == station].loc['2020-02-01'][time_col][:-1]

b = test[test['행정동명칭'] == '명동'][time_column[5:]].iloc[0]

df_1 = pd.DataFrame(a)

df_2 = pd.DataFrame(b)

df_1['행정동인구'] = b

# %%
a = down_data[down_data['역명'] == station].loc['2020-02-01'][time_col][:-1]

b = test[test['행정동명칭'] == '명동'][time_column[5:]].iloc[0]

df_1 = pd.DataFrame(a)

df_2 = pd.DataFrame(b)

df_1['행정동인구'] = b

df_1.reset_index(inplace = True)

# %%
a = down_data[down_data['역명'] == station].loc['2020-02-01'][time_col][:-1]

b = test[test['행정동명칭'] == '명동'][time_column[5:]].iloc[0]

df_1 = pd.DataFrame(a)

df_2 = pd.DataFrame(b)

df_1['행정동인구'] = b

df_1.reset_index(inplace = True)

df_1.columns = ['시간', '지하철인구', '행정동인구']

# %%
a = down_data[down_data['역명'] == station].loc['2020-02-01'][time_col][:-1]

b = test[test['행정동명칭'] == '명동'][time_column[5:]].iloc[0]

df_1 = pd.DataFrame(a)

df_2 = pd.DataFrame(b)

df_1['행정동인구'] = b

df_1.reset_index(inplace = True)

df_1.columns = ['시간', '지하철인구', '행정동인구']

df_1['행정동인구'] = df_2[2]

# %%
df_1['지하철승차인구'] = df_1_['지하철승차인구']

# %%
df_1 = df_1[['시간', '지하철승차인구', '지하철하차인구', '행정동인구']]

# %%
df_1['행정동인구'] = df_2[2]

# %%
df_1
# Out:
#          시간  지하철인구     행정동인구
# 0    06시 이전    7.0   1506.43
# 1   06 ~ 07  252.0   3603.61
# 2   07 ~ 08  208.0   4707.65
# 3   08 ~ 09  350.0   7198.98
# 4   09 ~ 10  583.0   9182.75
# 5   10 ~ 11  491.0   9864.41
# 6   11 ~ 12  468.0  10970.79
# 7   12 ~ 13  545.0  11471.71
# 8   13 ~ 14  481.0  11221.18
# 9   14 ~ 15  526.0  11188.64
# 10  15 ~ 16  622.0  10109.60
# 11  16 ~ 17  632.0  10587.30
# 12  17 ~ 18  810.0  10697.87
# 13  18 ~ 19  882.0   8781.11
# 14  19 ~ 20  607.0   6420.97
# 15  20 ~ 21  619.0   5091.03
# 16  21 ~ 22  670.0   5025.40
# 17  22 ~ 23  602.0   4415.18
# 18  23 ~ 24  489.0   3415.71

# %%
df_1['지하철승하차인구'] = df_1['지하철하차인구'] - df_1['지하철승차인구']
# Out:
# C:\Users\sb\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_1.corr()
# Out:
#            지하철승차인구   지하철하차인구     행정동인구  지하철승하차인구
# 지하철승차인구   1.000000  0.904303  0.408375 -0.983651
# 지하철하차인구   0.904303  1.000000  0.505276 -0.812643
# 행정동인구     0.408375  0.505276  1.000000 -0.344335
# 지하철승하차인구 -0.983651 -0.812643 -0.344335  1.000000

# %% [markdown]
# # 상관관계분석

# %%
ride_pop('명동', '2020-02-01')
# Out:
# 06시 이전       30.0
# 06 ~ 07      85.0
# 07 ~ 08     177.0
# 08 ~ 09     322.0
# 09 ~ 10     758.0
# 10 ~ 11     907.0
# 11 ~ 12    1200.0
# 12 ~ 13    1152.0
# 13 ~ 14    1254.0
# 14 ~ 15    1280.0
# 15 ~ 16    1532.0
# 16 ~ 17    1780.0
# 17 ~ 18    1948.0
# 18 ~ 19    2023.0
# 19 ~ 20    1799.0
# 20 ~ 21    1680.0
# 21 ~ 22    1808.0
# 22 ~ 23    1842.0
# 23 ~ 24     807.0
# Name: 2020-02-01 00:00:00, dtype: float64

# %%
quit_pop('명동', '2020-02-01')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-1627dec4c03c> in <module>
# ----> 1 quit_pop('명동', '2020-02-01')
#
# NameError: name 'quit_pop' is not defined

# %% [markdown]
# # 매핑을 해야한다
# - 지하철역과 연관지으려면, 해당 행정구역과 지하철역을 연결지어서 생각해야 한다
# - 좌표를 기준으로, 각 지하철역 좌표와 행정동 좌표를 비교해서, 가장 큰처의 지하철역으로 매핑을 시킬 수 있을까

# %% [markdown]
# # 회귀모형
# - 회귀모형을 하려면, 역시나 특정 행정구역과 지하철역을 연관지어야 한다
# - 지하철 역의 하차인원수가 X데이터가 될 것이고, 실제 유동인구가 Y데이터가 될 것

# %% [markdown]
# # 유동인구 데이터 매칭

# %% [markdown]
# ## 데이터 전처리

# %%
sub_loc = pd.read_csv('서울 지하철역 좌표.csv')

# %%
sub_loc
# Out:
#           역명                               상세주소          경도         위도   상태
# 0         서울        서울특별시 중구 봉래동2가 122 서울역(1호선)  126.969563  37.558156  정좌표
# 1         시청           서울특별시 중구 정동 5-5 시청역(1호선)  126.976919  37.565597  정좌표
# 2         종각          서울특별시 종로구 종로1가 54 종각지하철역사  126.981390  37.570222  정좌표
# 3       종로5가      서울특별시 종로구 종로5가 82-1 1호선 종로5가역  127.001925  37.571020  정좌표
# 4        동대문  서울특별시 종로구 창신동 492-1 1호선 동대문역(1호선)  127.011233  37.571759  정좌표
# ..       ...                                ...         ...        ...  ...
# 273  부천종합운동장      경기도 부천시 원미구 춘의동 15-1 부천종합운동장역  126.797466  37.505639   실패
# 274       춘의            경기도 부천시 원미구 춘의동 145 춘의역  126.787091  37.503859   실패
# 275      신중동         경기도 부천시 원미구 중동 1140-6 신중동역  126.775952  37.503189   실패
# 276     부천시청          경기도 부천시 원미구 중동 1243 부천시청역  126.764025  37.504748   실패
# 277       상동             경기도 부천시 원미구 상동 633 상동역  126.753153  37.505885   실패
#
# [278 rows x 5 columns]

# %%
dong_loc = pd.read_excel('4개지역_행정동.xlsx')

# %%
dong_loc['subway'] = 0

# %%
test = dong_loc[dong_loc['SIDO_CD'] == 11]

# %%
test
# Out:
#     STD_YYYY    HDONG_CD HDONG_NM  SIDO_CD SIDO_NM  SGNG_CD SGNG_NM  \
# 35      2020  1135059500     공릉1동       11   서울특별시    11350     노원구
# 36      2020  1135060000     공릉2동       11   서울특별시    11350     노원구
# 37      2020  1135072000    상계10동       11   서울특별시    11350     노원구
# 38      2020  1135063000     상계1동       11   서울특별시    11350     노원구
# 39      2020  1135064000     상계2동       11   서울특별시    11350     노원구
# 40      2020  1135066500   상계3.4동       11   서울특별시    11350     노원구
# 41      2020  1135067000     상계5동       11   서울특별시    11350     노원구
# 42      2020  1135069500   상계6.7동       11   서울특별시    11350     노원구
# 43      2020  1135070000     상계8동       11   서울특별시    11350     노원구
# 44      2020  1135071000     상계9동       11   서울특별시    11350     노원구
# 45      2020  1135056000     월계1동       11   서울특별시    11350     노원구
# 46      2020  1135057000     월계2동       11   서울특별시    11350     노원구
# 47      2020  1135058000     월계3동       11   서울특별시    11350     노원구
# ...

# %%
from haversine import haversine

# %%
dong_loc
# Out:
#     STD_YYYY    HDONG_CD HDONG_NM  SIDO_CD SIDO_NM  SGNG_CD SGNG_NM  \
# 0       2020  2726067000     고산1동       27   대구광역시    27260     수성구
# 1       2020  2726068000     고산2동       27   대구광역시    27260     수성구
# 2       2020  2726069000     고산3동       27   대구광역시    27260     수성구
# 3       2020  2726064000      두산동       27   대구광역시    27260     수성구
# 4       2020  2726055000     만촌1동       27   대구광역시    27260     수성구
# ..       ...         ...      ...      ...     ...      ...     ...
# 64      2020  1114068000      중림동       11   서울특별시    11140      중구
# 65      2020  1114064500      청구동       11   서울특별시    11140      중구
# 66      2020  1114057000       필동       11   서울특별시    11140      중구
# 67      2020  1114067000      황학동       11   서울특별시    11140      중구
# 68      2020  1114054000      회현동       11   서울특별시    11140      중구
#
#            AREA    LENGTH     X_COORD    Y_COORD  subway
# 0    8881312.38  17757.54  128.699631  35.811747       0
# ...

# %%
sub_loc
# Out:
#           역명                               상세주소          경도         위도   상태
# 0         서울        서울특별시 중구 봉래동2가 122 서울역(1호선)  126.969563  37.558156  정좌표
# 1         시청           서울특별시 중구 정동 5-5 시청역(1호선)  126.976919  37.565597  정좌표
# 2         종각          서울특별시 종로구 종로1가 54 종각지하철역사  126.981390  37.570222  정좌표
# 3       종로5가      서울특별시 종로구 종로5가 82-1 1호선 종로5가역  127.001925  37.571020  정좌표
# 4        동대문  서울특별시 종로구 창신동 492-1 1호선 동대문역(1호선)  127.011233  37.571759  정좌표
# ..       ...                                ...         ...        ...  ...
# 273  부천종합운동장      경기도 부천시 원미구 춘의동 15-1 부천종합운동장역  126.797466  37.505639   실패
# 274       춘의            경기도 부천시 원미구 춘의동 145 춘의역  126.787091  37.503859   실패
# 275      신중동         경기도 부천시 원미구 중동 1140-6 신중동역  126.775952  37.503189   실패
# 276     부천시청          경기도 부천시 원미구 중동 1243 부천시청역  126.764025  37.504748   실패
# 277       상동             경기도 부천시 원미구 상동 633 상동역  126.753153  37.505885   실패
#
# [278 rows x 5 columns]

# %%
test2 = test[['HDONG_NM', 'Y_COORD', 'X_COORD']]

# %%
test2.columns = ['행정동', '위도', '경도']

# %%
test2
# Out:
#        행정동         위도          경도
# 35    공릉1동  37.624093  127.072581
# 36    공릉2동  37.631583  127.094192
# 37   상계10동  37.659583  127.058356
# 38    상계1동  37.683400  127.064630
# 39    상계2동  37.656655  127.067094
# 40  상계3.4동  37.675752  127.083143
# 41    상계5동  37.663438  127.070177
# 42  상계6.7동  37.648597  127.060128
# 43    상계8동  37.666250  127.053644
# 44    상계9동  37.667674  127.062378
# 45    월계1동  37.621905  127.058408
# 46    월계2동  37.633978  127.051165
# 47    월계3동  37.624800  127.064712
# 48    중계1동  37.650111  127.073705
# 49  중계2.3동  37.643404  127.065856
# 50    중계4동  37.658576  127.083624
# 51    중계본동  37.647631  127.085488
# 52    하계1동  37.638544  127.075006
# 53    하계2동  37.634923  127.064952
# 54     광희동  37.565177  127.003693
# 55     다산동  37.555034  127.008419
# 56     동화동  37.560674  127.018648
# 57      명동  37.563586  126.984205
# 58     소공동  37.564293  126.974020
# 59    신당5동  37.563627  127.021838
# 60     신당동  37.565724  127.013671
# ...

# %%
sub_loc.reset_index(inplace=True)

# %%
sub_loc
# Out:
#      index       역명                               상세주소          경도         위도  \
# 0        0       서울        서울특별시 중구 봉래동2가 122 서울역(1호선)  126.969563  37.558156
# 1        1       시청           서울특별시 중구 정동 5-5 시청역(1호선)  126.976919  37.565597
# 2        2       종각          서울특별시 종로구 종로1가 54 종각지하철역사  126.981390  37.570222
# 3        3     종로5가      서울특별시 종로구 종로5가 82-1 1호선 종로5가역  127.001925  37.571020
# 4        4      동대문  서울특별시 종로구 창신동 492-1 1호선 동대문역(1호선)  127.011233  37.571759
# ..     ...      ...                                ...         ...        ...
# 273    273  부천종합운동장      경기도 부천시 원미구 춘의동 15-1 부천종합운동장역  126.797466  37.505639
# 274    274       춘의            경기도 부천시 원미구 춘의동 145 춘의역  126.787091  37.503859
# 275    275      신중동         경기도 부천시 원미구 중동 1140-6 신중동역  126.775952  37.503189
# 276    276     부천시청          경기도 부천시 원미구 중동 1243 부천시청역  126.764025  37.504748
# 277    277       상동             경기도 부천시 원미구 상동 633 상동역  126.753153  37.505885
#
#       상태
# 0    정좌표
# 1    정좌표
# ...

# %%
sub_test = sub_loc[['역명', '위도', '경도']]

# %%
sub_test.set_index('역명', inplace = True)

# %%
test2.set_index('행정동', inplace = True)

# %%
test2
# Out:
#                위도          경도
# 행정동
# 공릉1동    37.624093  127.072581
# 공릉2동    37.631583  127.094192
# 상계10동   37.659583  127.058356
# 상계1동    37.683400  127.064630
# 상계2동    37.656655  127.067094
# 상계3.4동  37.675752  127.083143
# 상계5동    37.663438  127.070177
# 상계6.7동  37.648597  127.060128
# 상계8동    37.666250  127.053644
# 상계9동    37.667674  127.062378
# 월계1동    37.621905  127.058408
# 월계2동    37.633978  127.051165
# 월계3동    37.624800  127.064712
# 중계1동    37.650111  127.073705
# 중계2.3동  37.643404  127.065856
# 중계4동    37.658576  127.083624
# 중계본동    37.647631  127.085488
# 하계1동    37.638544  127.075006
# 하계2동    37.634923  127.064952
# 광희동     37.565177  127.003693
# 다산동     37.555034  127.008419
# 동화동     37.560674  127.018648
# 명동      37.563586  126.984205
# 소공동     37.564293  126.974020
# 신당5동    37.563627  127.021838
# 신당동     37.565724  127.013671
# 약수동     37.550170  127.010301
# 을지로동    37.566585  126.996387
# 장충동     37.555864  127.001637
# 중림동     37.557356  126.966042
# ...

# %%
sub_test.loc['시청'].mean()
# Out:
# 위도     37.564578
# 경도    126.976211
# dtype: float64

# %%
test2['지하철역'] = 0
# Out:
# C:\Users\sb\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sub_test.loc['서울']['위도']
# Out:
# 37.5581563065703

# %%
sub_test.loc['서울']['위도'].mean()
# Out:
# 37.5581563065703

# %% [markdown]
# # 지역별 매칭

# %%
time2002
# Out:
#         기준년도     기준연월일       행정동코드 행정동명칭  TMST_00  TMST_01  TMST_02  TMST_03  \
# 0     202002  20200201  1114052000   소공동  1393.34  1144.91   900.51   721.78
# 1     202002  20200201  1114054000   회현동  1586.96  1170.81   898.06   682.55
# 2     202002  20200201  1114055000    명동  1534.52  1139.65  1015.20   799.85
# 3     202002  20200201  1114057000    필동  1321.52   933.49   803.40   690.18
# 4     202002  20200201  1114058000   장충동   629.17   561.68   454.77   372.22
# ...      ...       ...         ...   ...      ...      ...      ...      ...
# 1996  202002  20200229  2726066100  범물1동   485.96   388.68   348.90   289.15
# 1997  202002  20200229  2726066200  범물2동   947.07   896.23   851.62   794.46
# 1998  202002  20200229  2726067000  고산1동  2162.60  1758.41  1318.00  1203.27
# 1999  202002  20200229  2726068000  고산2동  2599.19  2085.08  1549.93  1509.08
# 2000  202002  20200229  2726069000  고산3동   953.12   774.17   597.53   535.36
#
# ...

# %%
test2 = pd.read_csv('행정구역 지하철역 매칭.csv')

# %%
sub_test.loc['노원']['위도'].mean(), sub_test.loc['노원']['경도'].mean()
# Out:
# (37.6548023609494, 127.0615745492935)

# %%
test2.set_index('행정동', inplace=True)

# %%
sub_test
# Out:
#                 위도          경도
# 역명
# 서울       37.558156  126.969563
# 시청       37.565597  126.976919
# 종각       37.570222  126.981390
# 종로5가     37.571020  127.001925
# 동대문      37.571759  127.011233
# ...            ...         ...
# 부천종합운동장  37.505639  126.797466
# 춘의       37.503859  126.787091
# 신중동      37.503189  126.775952
# 부천시청     37.504748  126.764025
# 상동       37.505885  126.753153
#
# [278 rows x 2 columns]

# %%
test2.drop('지하철역', axis=1, inplace=True)

# %%
test2
# Out:
#                위도          경도  지하철역
# 행정동
# 공릉1동    37.624093  127.072581     0
# 공릉2동    37.631583  127.094192     0
# 상계10동   37.659583  127.058356     0
# 상계1동    37.683400  127.064630     0
# 상계2동    37.656655  127.067094     0
# 상계3.4동  37.675752  127.083143     0
# 상계5동    37.663438  127.070177     0
# 상계6.7동  37.648597  127.060128     0
# 상계8동    37.666250  127.053644     0
# 상계9동    37.667674  127.062378     0
# 월계1동    37.621905  127.058408     0
# 월계2동    37.633978  127.051165     0
# 월계3동    37.624800  127.064712     0
# 중계1동    37.650111  127.073705     0
# 중계2.3동  37.643404  127.065856     0
# 중계4동    37.658576  127.083624     0
# 중계본동    37.647631  127.085488     0
# 하계1동    37.638544  127.075006     0
# 하계2동    37.634923  127.064952     0
# 광희동     37.565177  127.003693     0
# 다산동     37.555034  127.008419     0
# 동화동     37.560674  127.018648     0
# 명동      37.563586  126.984205     0
# 소공동     37.564293  126.974020     0
# 신당5동    37.563627  127.021838     0
# ...

# %%
close_station = {'행정구역' : [],
                '지하철역' : []}

for dong in test2.index:
    start = (test2.loc[dong]['위도'], test2.loc[dong]['경도'])
    distance_dic = {}
    for station in sub_test.index:
        goal = (sub_test.loc[station]['위도'].mean(), sub_test.loc[station]['경도'].mean())
        distance_dic[station] = haversine(start, goal)
    close_ = sorted((value, key) for key, value in distance_dic.items())[0][1]
    close_station['행정구역'].append(dong)
    close_station['지하철역'].append(close_)

# %%
station_mapping = pd.DataFrame(close_station)
station_mapping
# Out:
#       행정구역         지하철역
# 0     공릉1동  공릉(서울과학기술대)
# 1     공릉2동  화랑대(서울여대입구)
# 2    상계10동           노원
# 3     상계1동          수락산
# 4     상계2동           노원
# 5   상계3.4동          당고개
# 6     상계5동           상계
# 7   상계6.7동           노원
# 8     상계8동           마들
# 9     상계9동           마들
# 10    월계1동           석계
# 11    월계2동           하계
# 12    월계3동  공릉(서울과학기술대)
# 13    중계1동           중계
# 14  중계2.3동           중계
# 15    중계4동           상계
# 16    중계본동           상계
# 17    하계1동           하계
# 18    하계2동           하계
# 19     광희동    동대문역사문화공원
# 20     다산동           약수
# 21     동화동           청구
# 22      명동        을지로입구
# 23     소공동           시청
# 24    신당5동           신당
# 25     신당동           신당
# 26     약수동         버티고개
# 27    을지로동        을지로4가
# 28     장충동         동대입구
# 29     중림동           서울
# 30     청구동           청구
# 31      필동          충무로
# 32     황학동           신당
# 33     회현동    회현(남대문시장)

# %%
test2.reset_index(inplace=True)

# %%
test2['지하철역'] = station_mapping['지하철역']

# %%
test2
# Out:
#        행정동         위도          경도         지하철역
# 0     공릉1동  37.624093  127.072581  공릉(서울과학기술대)
# 1     공릉2동  37.631583  127.094192  화랑대(서울여대입구)
# 2    상계10동  37.659583  127.058356           노원
# 3     상계1동  37.683400  127.064630          수락산
# 4     상계2동  37.656655  127.067094           노원
# 5   상계3.4동  37.675752  127.083143          당고개
# 6     상계5동  37.663438  127.070177           상계
# 7   상계6.7동  37.648597  127.060128           노원
# 8     상계8동  37.666250  127.053644           마들
# 9     상계9동  37.667674  127.062378           마들
# 10    월계1동  37.621905  127.058408           석계
# 11    월계2동  37.633978  127.051165           하계
# 12    월계3동  37.624800  127.064712  공릉(서울과학기술대)
# 13    중계1동  37.650111  127.073705           중계
# 14  중계2.3동  37.643404  127.065856           중계
# 15    중계4동  37.658576  127.083624           상계
# 16    중계본동  37.647631  127.085488           상계
# 17    하계1동  37.638544  127.075006           하계
# 18    하계2동  37.634923  127.064952           하계
# ...

# %% [markdown]
# # 지하철역 행정구역 상관관계

# %%
Seoul_data = time2002

# %%
Seoul_data
# Out:
#         기준년도     기준연월일       행정동코드 행정동명칭  TMST_00  TMST_01  TMST_02  TMST_03  \
# 0     202002  20200201  1114052000   소공동  1393.34  1144.91   900.51   721.78
# 1     202002  20200201  1114054000   회현동  1586.96  1170.81   898.06   682.55
# 2     202002  20200201  1114055000    명동  1534.52  1139.65  1015.20   799.85
# 3     202002  20200201  1114057000    필동  1321.52   933.49   803.40   690.18
# 4     202002  20200201  1114058000   장충동   629.17   561.68   454.77   372.22
# ...      ...       ...         ...   ...      ...      ...      ...      ...
# 1996  202002  20200229  2726066100  범물1동   485.96   388.68   348.90   289.15
# 1997  202002  20200229  2726066200  범물2동   947.07   896.23   851.62   794.46
# 1998  202002  20200229  2726067000  고산1동  2162.60  1758.41  1318.00  1203.27
# 1999  202002  20200229  2726068000  고산2동  2599.19  2085.08  1549.93  1509.08
# 2000  202002  20200229  2726069000  고산3동   953.12   774.17   597.53   535.36
#
# ...

# %%
# Seoul_data = 2020.02 행정동별 인구데이터
Seoul_data[Seoul_data['행정동명칭'] == '공릉1동'][time_column[4:]]
# Out:
#       TMST_04  TMST_05  TMST_06   TMST_07   TMST_08  TMST_09  TMST_10  \
# 18    1688.05  2095.13  3046.89   3715.34   5476.58  6266.42  6657.81
# 87    1513.86  1695.33  2351.17   2904.45   3680.00  5007.42  5712.92
# 156   1356.34  2253.44  4899.67  10147.81  12953.23  9332.77  6835.16
# 225   1452.76  2222.34  4084.80   8242.00  12068.70  8707.83  7003.25
# 294   1480.26  2100.20  4123.27   7942.17  12064.93  7896.08  6518.71
# 363   1518.99  2093.79  3912.02   8373.00  12110.77  8395.15  6983.46
# 432   1611.12  2309.53  3913.17   7998.71  12116.28  8688.67  7143.39
# 501   1747.68  2250.34  3253.58   3722.64   5855.44  6934.88  6927.28
# 570   1543.20  1775.91  2332.65   2998.98   3720.95  5007.93  5861.11
# 639   1467.45  2232.92  4764.90   9051.42  12290.83  8465.51  6863.42
# 708   1556.78  2265.64  4252.90   8400.45  12313.70  8620.88  7040.66
# 777   1579.34  2147.15  4002.66   7995.59  11370.60  8206.08  6822.39
# ...

# %%
target =  Seoul_data[Seoul_data['행정동명칭'] == '공릉1동'][time_column[5:]].stack()

# %%
target
# Out:
# 18    TMST_05    2095.13
#       TMST_06    3046.89
#       TMST_07    3715.34
#       TMST_08    5476.58
#       TMST_09    6266.42
#                   ...
# 1950  TMST_19    5967.33
#       TMST_20    5465.43
#       TMST_21    5145.76
#       TMST_22    4576.79
#       TMST_23    3540.22
# Length: 551, dtype: float64

# %%
test2
# Out:
#        행정동         위도          경도  지하철역
# 0     공릉1동  37.624093  127.072581     0
# 1     공릉2동  37.631583  127.094192     0
# 2    상계10동  37.659583  127.058356     0
# 3     상계1동  37.683400  127.064630     0
# 4     상계2동  37.656655  127.067094     0
# 5   상계3.4동  37.675752  127.083143     0
# 6     상계5동  37.663438  127.070177     0
# 7   상계6.7동  37.648597  127.060128     0
# 8     상계8동  37.666250  127.053644     0
# 9     상계9동  37.667674  127.062378     0
# 10    월계1동  37.621905  127.058408     0
# 11    월계2동  37.633978  127.051165     0
# 12    월계3동  37.624800  127.064712     0
# 13    중계1동  37.650111  127.073705     0
# 14  중계2.3동  37.643404  127.065856     0
# 15    중계4동  37.658576  127.083624     0
# 16    중계본동  37.647631  127.085488     0
# 17    하계1동  37.638544  127.075006     0
# 18    하계2동  37.634923  127.064952     0
# 19     광희동  37.565177  127.003693     0
# 20     다산동  37.555034  127.008419     0
# 21     동화동  37.560674  127.018648     0
# ...

# %%
test2
# Out:
#        행정동         위도          경도  지하철역
# 0     공릉1동  37.624093  127.072581     0
# 1     공릉2동  37.631583  127.094192     0
# 2    상계10동  37.659583  127.058356     0
# 3     상계1동  37.683400  127.064630     0
# 4     상계2동  37.656655  127.067094     0
# 5   상계3.4동  37.675752  127.083143     0
# 6     상계5동  37.663438  127.070177     0
# 7   상계6.7동  37.648597  127.060128     0
# 8     상계8동  37.666250  127.053644     0
# 9     상계9동  37.667674  127.062378     0
# 10    월계1동  37.621905  127.058408     0
# 11    월계2동  37.633978  127.051165     0
# 12    월계3동  37.624800  127.064712     0
# 13    중계1동  37.650111  127.073705     0
# 14  중계2.3동  37.643404  127.065856     0
# 15    중계4동  37.658576  127.083624     0
# 16    중계본동  37.647631  127.085488     0
# 17    하계1동  37.638544  127.075006     0
# 18    하계2동  37.634923  127.064952     0
# 19     광희동  37.565177  127.003693     0
# 20     다산동  37.555034  127.008419     0
# 21     동화동  37.560674  127.018648     0
# ...

# %%
len(target)
# Out:
# 551

# %%
test2.drop('지하철역', axis=0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-117-dc98022bd10e> in <module>
# ----> 1 test2.drop('지하철역', axis=0, inplace=True)
#
# ~\anaconda3\envs\nlp\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\envs\nlp\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
Seoul_mapping = test2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-04c449020063> in <module>
# ----> 1 Seoul_mapping = test2
#
# NameError: name 'test2' is not defined

# %%
len(Seoul_data[Seoul_data['행정동명칭'] == '공릉1동'].iloc[0][time_column[5:]])

# %%
quit_pop(Seoul_mapping.loc['공릉1동']['지하철역'], '2020-02-01')

# %%
station_list = list(up_data['역명'])

# %%
sub_df = pd.DataFrame(columns=['지하철인구'])

# %%
quit_pop

# %%
sub_df = pd.DataFrame(quit_pop(Seoul_mapping.loc['공릉1동']['지하철역'], '2020-02-01'))

# %%
down_data.loc['2020-02-3']

# %%
for i in range(2, 30, 1):
    sub_df[i] = quit_pop(Seoul_mapping.loc['공릉1동']['지하철역'], '2020-02-{}'.format(i))

# %%
sub_df_test = sub_df.T

# %%
sub_df_test.drop('1', axis=0, inplace=True)

# %%
sub_df_test.reset_index(inplace=True)

# %%
date = []

for i in range(1, 30, 1):
    date.append('2020-02-{:02}'.format(i))

# %%
date

# %%
sub_df_test['index'] = date

# %%
sub_df_test.set_index('index', inplace=True)

# %%
sub_df_test

# %%
sub_df_test.stack()

# %%
station_list.sort()
set(station_list)

# %%
ride_pop('공릉', '2020-02-01')

# %%
x1 = sub_test.loc['서울']['위도'] 
y1 = sub_test.loc['서울']['경도'] 
loc2 = (x1, y1)

# %% [markdown]
# # 각 지역별로 평균내기

# %%
time2004['HDONG_NM']

# %%
time2004[time2004['HDONG_NM'] == '명동']['TMST_06'].mean()

# %%
test1[test1['사용월'] == 202004]
