# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from dbfread import DBF
from haversine import haversine
from tqdm.notebook import tqdm
# %matplotlib inline
import platform
import pickle
import re
platform.system()
if platform.system() == 'Darwin': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif platform.system() == 'Windows': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정
# %config InlineBackend.figure_format = 'retina'
# !pip install dbfread
# !pip install haversine
# Out:
# Requirement already satisfied: dbfread in c:\users\user\anaconda3\lib\site-packages (2.0.7)
# Requirement already satisfied: haversine in c:\users\user\anaconda3\lib\site-packages (2.2.0)

# %%
def pklopen(route):
    with open('./{}'.format(route), 'rb') as f:
        df = pickle.load(f)
    return df

# %%
# bus_up_1 = pklopen()
# bus_down_1 = pklopen()
# bus_up_2 = pklopen()
# bus_down_2 = pklopen()
# bus_up_3 = pklopen()
# bus_down_3 = pklopen()
# bus_up_4 = pklopen()
# bus_down_4 = pklopen()
# bus_up_5 = pklopen()
bus_down_5 = pklopen('bus_down_5.pkl')

# %%
def eachbus(df, date, station, *time):
    if time:
        df_sum = df.groupby(['사용일자', '지하철역']).sum()
        df_date = df_sum.loc[date]
        df_station = df_date.loc[station]
        people_num = df_station.loc[time]
        return people_num
    else:
        df_sum = df.groupby(['사용일자', '지하철역']).sum()
        df_date = df_sum.loc[date]
        df_station = df_date.loc[station]
        return df_station.to_frame().T

# %%
bus_down_5
# Out:
#             사용일자   지하철역                역명    06시 이전  06 ~ 07  07 ~ 08  \
# 0       20200501   가락시장          가락시장.가락몰   4.11457  16.1497  17.1783
# 1       20200501   가락시장        가락시장.가락시장역   29.0758  114.123  121.392
# 2       20200501   가락시장            가락시장남문   2.14736  8.42839  8.96523
# 3       20200501   가락시장             가락시장역   2.42839  9.53144  10.1385
# 4       20200501   가락시장           건너말공원입구   2.47163  9.70113   10.319
# ...          ...    ...               ...       ...      ...      ...
# 197640  20200531  효창공원앞  효창공원삼거리.윤봉길의사등묘역  0.418023  1.83287  2.12227
# 197641  20200531  효창공원앞            효창공원앞역    3.8551  16.9031  19.5721
# 197642  20200531  효창공원앞             효창공원역  0.768956  3.37158  3.90393
# 197643  20200531  효창공원앞            효창공원후문   1.78563   7.8293   9.0655
# 197644  20200531  효창공원앞     효창운동장.효창동주민센터  0.608972  2.67011   3.0917
#
#         08 ~ 09  09 ~ 10  10 ~ 11  11 ~ 12  ...  15 ~ 16  16 ~ 17  17 ~ 18  \
# 0       33.7909  33.0195  29.6764  32.4023  ...  40.1685  40.5286  45.4146
# 1       238.785  233.334   209.71  228.972  ...  283.853  286.397  320.925
# 2       17.6352  17.2326  15.4878  16.9105  ...  20.9636  21.1515  23.7015
# 3       19.9432  19.4878  17.5148  19.1236  ...  23.7072  23.9197  26.8034
# 4       20.2982  19.8348  17.8266  19.4641  ...  24.1293  24.3455  27.2806
# ...         ...      ...      ...      ...  ...      ...      ...      ...
# 197640  2.66892  3.85867  3.85867  3.34418  ...   5.7237  5.98094   7.1707
# 197641  24.6133  35.5855  35.5855  30.8408  ...  52.7852  55.1576  66.1298
# 197642  4.90949  7.09805  7.09805  6.15165  ...  10.5288   11.002  13.1906
# 197643  11.4006  16.4827  16.4827   14.285  ...  24.4494  25.5482  30.6304
# 197644  3.88805  5.62128  5.62128  4.87177  ...  8.33823  8.71298  10.4462
#
#         18 ~ 19  19 ~ 20  20 ~ 21  21 ~ 22  22 ~ 23  23 ~ 24    24시 이후
# 0       44.4374  36.5683   28.442  24.9446  25.2532  14.6582   6.58332
# 1       314.019  258.412  200.987  176.272  178.453  103.583   46.5213
# 2       23.1915  19.0847  14.8436  13.0184  13.1794  7.64997   3.43578
# 3       26.2266  21.5823  16.7863  14.7221  14.9043  8.65114   3.88543
# 4       26.6936  21.9666  17.0851  14.9842  15.1696  8.80517    3.9546
# ...         ...      ...      ...      ...      ...      ...       ...
# 197640  5.56292  6.27035  5.24137  4.98412  4.50179  2.82969  0.192934
# 197641  51.3025  57.8265   48.337  45.9647  41.5165  26.0961   1.77928
# 197642   10.233  11.5343  9.64152  9.16832  8.28106  5.20524  0.354903
# 197643  23.7626  26.7844   22.389  21.2902  19.2299  12.0873  0.824137
# 197644  8.10401  9.13458  7.63557  7.26082  6.55816  4.12227  0.281064
#
# [197645 rows x 23 columns]

# %%
eachbus(bus_down_5, 20200501,'가락시장', '06 ~ 07')
# Out:
# 212.6613222842731

# %%
eachbus(bus_down_5, 20200501, '가락시장')
# Out:
#                                                      역명   06시 이전  06 ~ 07  \
# 가락시장  가락시장.가락몰가락시장.가락시장역가락시장남문가락시장역건너말공원입구경찰병원.서울동부고...  54.1812  212.661
#
#       07 ~ 08  08 ~ 09  09 ~ 10  10 ~ 11  11 ~ 12  12 ~ 13  13 ~ 14  ...  \
# 가락시장  226.207  444.963  434.804  390.782  426.677  428.032  401.618  ...
#
#       15 ~ 16  16 ~ 17  17 ~ 18  18 ~ 19  19 ~ 20  20 ~ 21  21 ~ 22  22 ~ 23  \
# 가락시장  528.944  533.685  598.025  585.157  481.536  374.528  328.474  332.537
#
#       23 ~ 24 24시 이후
# 가락시장  193.021  86.69
#
# [1 rows x 21 columns]

# %%
bus_down_5.groupby(['사용일자', '지하철역']).sum()
# Out:
#                                                                      역명  \
# 사용일자     지하철역
# 20200501 가락시장         가락시장.가락몰가락시장.가락시장역가락시장남문가락시장역건너말공원입구경찰병원.서울동부고...
#          가산디지털단지      7호선가산디지털단지역KCC웰츠밸리LG전자LG전자.W몰LG전자가산ASG세계물산STXV...
#          강남           2호선강남역강남역강남역.9번출구강남역.강남역사거리강남역.삼성전자강남역.서초초교앞강남...
#          강남구청         강남교육청강남구청.강남세무서강남구청역강남보건소.강남구립국제교육원라마다서울호텔앞삼성2...
#          강동           강동성심병원(동신중학교)강동역강동역.강풀만화거리입구강동역1번출구.동신중학교길동사거리...
# ...                                                                 ...
# 20200531 홍제           가산빌라간호대입구간호대정문갑을씨티텔앞개미마을경진빌라고은초등학교.홍제센트럴아이파크구룡...
#          화곡           가로공원.나누리병원가로공원공영주차장가로공원공영주차장.신영시장강서구립봉제산어르신복지센...
#          화랑대(서울여대입구)  경춘선숲길.토끼굴앞공릉동두산아파트세방아파트입구신내4단지아파트안마을예수사랑교회원묵고등...
#          회현(남대문시장)    교육연구정보원남대문시장남대문시장.회현역남대문시장악세사리전문상가남대문시장앞.이회영활동...
#          효창공원앞        국민은행효창동지점남이장군사당남정초등학교대한노인회도원삼성래미안아파트도원삼성래미안아파트...
#
#                           06시 이전     06 ~ 07      07 ~ 08      08 ~ 09  \
# 사용일자     지하철역
# 20200501 가락시장          54.181229  212.661322   226.206629   444.963340
#          가산디지털단지      209.659765  763.537053  1458.230602  4017.957280
#          강남            92.489771  450.293055   899.529084  1694.941113
#          강남구청          38.841991  278.367605   521.777417  1219.638528
#          강동            17.264985  127.656256   160.616683   301.875655
# ...                          ...         ...          ...          ...
# 20200531 홍제            93.060852  568.335920   525.129096   900.696107
#          화곡            42.683862  274.396255   228.663546   323.177811
#          화랑대(서울여대입구)   36.165481  135.620553   169.525692   345.832411
#          회현(남대문시장)      6.522003  134.166920   210.567527   338.212443
#          효창공원앞         37.348551  163.759031   189.615721   238.456133
#
#                           09 ~ 10      10 ~ 11      11 ~ 12      12 ~ 13  \
# 사용일자     지하철역
# 20200501 가락시장          434.804360   390.782111   426.677175   428.031706
#          가산디지털단지      4997.412598  3201.222973  3282.583479  3248.161726
#          강남           2813.274569  1939.642620  1693.355574  1857.194596
#          강남구청         1742.710678   833.808081   731.524170   643.482323
#          강동            290.365664   254.266149   223.398448   240.140252
# ...                           ...          ...          ...          ...
# 20200531 홍제           1216.438285  1419.178000  1007.051367  1276.263119
#          화곡            501.535377   556.414628   538.121544   868.921473
#          화랑대(서울여대입구)   490.494335   413.642688   458.849539   386.518577
#          회현(남대문시장)     975.505311   886.060698   763.074355   696.922610
#          효창공원앞         344.755855   344.755855   298.788408   316.026201
#
#                           13 ~ 14  ...      15 ~ 16      16 ~ 17      17 ~ 18  \
# 사용일자     지하철역                      ...
# 20200501 가락시장          401.618357  ...   528.944244   533.685102   598.025311
#          가산디지털단지      3326.392982  ...  3351.426983  2575.372929  2368.842415
#          강남           2107.709746  ...  1842.396233  1975.581503  2296.388879
#          강남구청          683.619048  ...   567.093074   534.724747   558.029942
#          강동            291.412027  ...   313.908826   346.346072   443.657808
# ...                           ...  ...          ...          ...          ...
# 20200531 홍제           1651.830131  ...  1798.068613  2196.900838  2180.282828
#          화곡            963.435739  ...  1152.464270  1378.078968  1538.143450
#          화랑대(서울여대입구)   490.494335  ...   526.659816   571.866667   630.635573
#          회현(남대문시장)     595.365706  ...   418.339909   318.646434   260.880121
#          효창공원앞         508.514887  ...   511.387852   534.371576   640.671298
#
#                           18 ~ 19      19 ~ 20      20 ~ 21      21 ~ 22  \
# 사용일자     지하철역
# 20200501 가락시장          585.157269   481.535669   374.527743   328.473698
#          가산디지털단지      2143.536399  1282.992589  1085.849826   791.700305
#          강남           2422.703480  1544.843427  1025.843685   818.666599
#          강남구청          504.945887   384.535714   274.483405   244.704545
#          강동            480.803686   363.087876   311.816101   330.127449
# ...                           ...          ...          ...          ...
# 20200531 홍제           2316.550505  1814.686622  1734.920177  1894.453067
#          화곡           1370.456850  1358.261461  1474.117657  1464.971116
#          화랑대(서울여대입구)   610.292490   587.689065   571.866667   664.540711
#          회현(남대문시장)     177.025797   121.122914    82.922610   136.030349
#          효창공원앞         497.023025   560.228265   468.293370   445.309647
#
#                           22 ~ 23     23 ~ 24      24시 이후
# 사용일자     지하철역
# 20200501 가락시장          332.537291  193.020627   86.689966
#          가산디지털단지       854.285310  616.462293  122.040759
#          강남            646.371369  511.600560    0.000000
#          강남구청          207.157287  152.778499   12.947330
#          강동            322.802910  268.915228   20.927255
# ...                           ...         ...         ...
# 20200531 홍제           1691.713353  960.520941    9.970806
#          화곡           1376.554545  763.736242   53.354827
#          화랑대(서울여대입구)   528.920158  440.766798   29.384453
#          회현(남대문시장)      88.512898   44.722307    3.726859
#          효창공원앞         402.215165  252.820961   17.237793
#
# [6882 rows x 21 columns]
