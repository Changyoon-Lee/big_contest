# %%
import pandas as pd
import pickle
df_seoul = pd.read_pickle('seoul_신한카드.pkl')
df_dong_code = pd.read_excel('2020빅콘테스트 문제데이터(혁신아이디어분야)/02_카드매출데이터(신한카드)/02_혁신아이디어분야_카드소비데이터(신한카드)_데이터정의서.xlsx',
                            sheet_name='(참고) 행정동코드', skiprows=1)
df_upjong_code = pd.read_excel('2020빅콘테스트 문제데이터(혁신아이디어분야)/02_카드매출데이터(신한카드)/02_혁신아이디어분야_카드소비데이터(신한카드)_데이터정의서.xlsx',
                            sheet_name='(참고) 업종코드', skiprows=1)
df_upjong_code = df_upjong_code[['업종코드 (32개 분류)']]
df_upjong_code.dropna(inplace=True)

# %%
import re
upjong_dic={}
gu_dic={}
dong_dic={}
for i,j in zip(df_dong_code['구코드'], df_dong_code['구명']):
    gu_dic[i]=j
for i,j in zip(df_dong_code['행정동코드'], df_dong_code['행정동명']):
    dong_dic[i]=j
for i in df_upjong_code.values:
    key = re.findall('\((.*)\)',i[0])[0]
    val = re.findall('(.*)\(',i[0])[0]
    upjong_dic[key]=val

# %%
#type 바꿔주기
df_seoul['기준일자'] = df_seoul['기준일자'].astype(str)
df_seoul['기준일자'] = pd.to_datetime(df_seoul['기준일자'].values)
df_seoul['업종코드'] = df_seoul['업종코드'].astype(str)

#시구, 동, 업종코드 mapping
df_seoul['시_구'] = df_seoul.index.map(gu_dic)
df_seoul['행정동'] = df_seoul['행정동코드'].map(dong_dic)
df_seoul['업종'] = df_seoul['업종코드'].map(upjong_dic)

# %%
df_seoul
# Out:
#           기준일자  행정동코드 업종코드 성별코드  나이코드  이용건수  이용금액     건별 이용금액    업종     시_구  \
# 구코드
# 140 2019-02-01    520   10    F    20    14  1038   74.142857    숙박   서울 중구
# 140 2019-02-01    520   10    F    25    59  4635   78.559322    숙박   서울 중구
# 140 2019-02-01    520   10    F    30    41  3046   74.292683    숙박   서울 중구
# 140 2019-02-01    520   10    F    35    59  5995  101.610169    숙박   서울 중구
# 140 2019-02-01    520   10    F    40    45  5172  114.933333    숙박   서울 중구
# ..         ...    ...  ...  ...   ...   ...   ...         ...   ...     ...
# 350 2020-05-31    720   81    M    45    19   127    6.684211  음료식품  서울 노원구
# 350 2020-05-31    720   81    M    50    33   211    6.393939  음료식품  서울 노원구
# 350 2020-05-31    720   81    M    55     9    61    6.777778  음료식품  서울 노원구
# 350 2020-05-31    720   81    M    60    19   194   10.210526  음료식품  서울 노원구
# 350 2020-05-31    720   81    M    65     5    29    5.800000  음료식품  서울 노원구
#
#        행정동
# 구코드
# 140   범어2동
# 140   범어2동
# 140   범어2동
# 140   범어2동
# 140   범어2동
# ..     ...
# 350  상계10동
# 350  상계10동
# 350  상계10동
# 350  상계10동
# 350  상계10동
#
# [1428518 rows x 11 columns]

# %% [markdown]
# 구별 (업종별, 성별, 나이별, (이용금액,건수))
# 140:중구, 350:노원구

# %%
df_set={}

# %%
df_set['동별'] = df_seoul[df_seoul['시_구']=='서울 중구'].groupby(['행정동','기준일자'],as_index=True).sum()[['이용건수','이용금액']]
df_set['업종별'] = df_seoul[df_seoul['시_구']=='서울 중구'].groupby(['업종','기준일자'],as_index=True).sum()[['이용건수','이용금액']]

# %%
df1 = df_set['업종별']

# %%
upjong_dic.values()
# Out:
# dict_values(['숙박', '레저용품', '레저업소', '문화취미', '가구', '전기', '주방용구', '연료판매', '광학제품', '가전', '유통업', '의복', '직물', '신변잡화', '서적문구', '사무통신', '자동차판매', '자동차정비', '의료기관', '보건위생', '요식업소', '음료식품', '수리서비스', '숙박', '레저용품', '레저업소', '문화취미', '가구', '전기', '주방용구', '연료판매', '광학제품', '가전', '유통업', '의복', '직물', '신변잡화', '서적문구', '사무통신', '자동차판매', '자동차정비', '의료기관', '보건위생', '요식업소', '음료식품', '수리서비스'])

# %%
for i in upjong_dic.values():
    try:
        df1 = df_set['업종별']
        df1 = df1.loc[i]
        df1['월일'] = df1.index.strftime('%m-%d')
        df1['년도'] = df1.index.strftime('%Y')

        df2 = df1[df1['년도']=='2019']

        df3 = df1[df1['년도']=='2020']
        df4 = df2[['월일']][1:]

        df4['이용건수(19)']=df2['이용건수'][1:].values
        df4['이용금액(19)']=df2['이용금액'][1:].values
        df4['이용건수(20)']=df3['이용건수'][:-2].values
        df4['이용금액(20)']=df3['이용금액'][:-2].values

        df4.reset_index(inplace=True)

        df4.set_index('월일',inplace=True)

        plt.figure(figsize=(20,10))
        df4['20-19'] = df4['이용건수(20)']-df4['이용건수(19)']
        plt.title(i)
        plt.plot(df4['20-19'])
    except:print(i)
# Out:
# 전기
# 주방용구
# 수리서비스
# 전기
# 주방용구
# C:\Users\YOON\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:22: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# 수리서비스

# %%
# Out:
#             이용건수   이용금액     월일    년도
# 기준일자
# 2019-02-01    14   2554  02-01  2019
# 2019-02-02    39  10284  02-02  2019
# 2019-02-03     5    407  02-03  2019
# 2019-02-05     5   6192  02-05  2019
# 2019-02-06    20  10021  02-06  2019
# ...          ...    ...    ...   ...
# 2020-05-27    45  16531  05-27  2020
# 2020-05-28    64  48269  05-28  2020
# 2020-05-29    67  15171  05-29  2020
# 2020-05-30    69  21393  05-30  2020
# 2020-05-31    78  41728  05-31  2020
#
# [239 rows x 4 columns]

# %%
# Out:
#             이용건수   이용금액     월일    년도
# 기준일자
# 2019-02-01    14   2554  02-01  2019
# 2019-02-02    39  10284  02-02  2019
# 2019-02-03     5    407  02-03  2019
# 2019-02-05     5   6192  02-05  2019
# 2019-02-06    20  10021  02-06  2019
# ...          ...    ...    ...   ...
# 2019-05-27    30  13220  05-27  2019
# 2019-05-28    33  20585  05-28  2019
# 2019-05-29    50  17671  05-29  2019
# 2019-05-30    40  16952  05-30  2019
# 2019-05-31    32   9158  05-31  2019
#
# [119 rows x 4 columns]

# %%
# Out:
#                월일
# 기준일자
# 2019-02-02  02-02
# 2019-02-03  02-03
# 2019-02-05  02-05
# 2019-02-06  02-06
# 2019-02-07  02-07
# ...           ...
# 2019-05-27  05-27
# 2019-05-28  05-28
# 2019-05-29  05-29
# 2019-05-30  05-30
# 2019-05-31  05-31
#
# [118 rows x 1 columns]

# %%
# Out:
#             기준일자  이용건수(19)  이용금액(19)  이용건수(20)  이용금액(20)
# 월일
# 02-02 2019-02-02        39     10284        58     23342
# 02-03 2019-02-03         5       407        20     44001
# 02-05 2019-02-05         5      6192        24     23498
# 02-06 2019-02-06        20     10021        24      8269
# 02-07 2019-02-07        44     11160        56     16594
# ...          ...       ...       ...       ...       ...
# 05-27 2019-05-27        30     13220       101     28667
# 05-28 2019-05-28        33     20585        55     13585
# 05-29 2019-05-29        50     17671        45     16531
# 05-30 2019-05-30        40     16952        64     48269
# 05-31 2019-05-31        32      9158        67     15171
#
# [118 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df1.loc['가구'])
# Out:
# [<matplotlib.lines.Line2D at 0x1e2816dee80>,
#  <matplotlib.lines.Line2D at 0x1e281deb7f0>]
