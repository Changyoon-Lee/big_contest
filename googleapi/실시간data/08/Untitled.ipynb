# %%
import pickle

# %%
with open('083007.pickle','rb') as f:
    data = pickle.load(f)

# %%
import pandas as pd
a = pd.DataFrame(data['cafe'])
a
# Out:
#                              id                          name  \
# 0   ChIJ6f8mgmS5fDURt-_aG_Bkla0                   Cafe 감나무 아래
# 1   ChIJPakaOwajfDURCTBVfkMuZgE        바캉스커피(vacances coffee)
# 2   ChIJuc-3YO6ifDURqO3LmzsRQaU                 스타벅스 을지로국제빌딩점
# 3   ChIJX2T9De-ifDURgiWDTr4Av3U                 스타벅스 을지로삼화타워점
# 4   ChIJ712FUOWifDURMrEzYFDR8vo                 Coffee Libre.
# 5   ChIJP-amieWifDUR_NFabQVokYU                      이디야 IBK점
# 6   ChIJh2yn4e-ifDURldl8mjVAGJ0               A Twosome Place
# 7   ChIJczT11O2ifDURLQYkK5wOu7Q                         다동커피집
# 8   ChIJ4WyI75yjfDURNohpjlT-7tM      Center Coffee Myeongdong
# 9   ChIJWavBvu2ifDURUZ9Au3aEVvs                    Cafe Mamas
# 10  ChIJfzajpe2ifDURYWKnoGMYY24                     Starbucks
# 11  ChIJGag47ACjfDURYZFr00VCuF4                    커피앳웍스 센터원점
# 12  ChIJjQPoJvCifDURNwpFEV0G7pQ                    SPE COFFEE
# 13  ChIJIbVZ0O-ifDURJlV_DDPZG6A                        스타사주카페
# ...
